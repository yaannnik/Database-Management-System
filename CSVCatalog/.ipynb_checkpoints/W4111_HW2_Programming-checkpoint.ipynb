# %% [markdown]
# <style  type="text/css">
# </style>
#
# <b><center>
# <span style="font-size: 24pt; line-height: 1.2">
# COMS W4111-002 (Fall 2021)<br>Introduction to Databases
# </span>
# </center></b>
# </span><br>
# <p>
# <i><center>
# <span style="font-size: 20pt; line-height: 1.2">
# Homework 2: Programming Implement a Simple Database Engine<br>15 Points
# </span>
# </center></i>

# %% [markdown]
# ## This assignment is due October 22, 11:59 pm EDT

# %% [markdown]
# __Note:__ Please replace the information below with your last name, first name and UNI.<br><br>
#
#
#
# <i>
# <span style="font-size: 20pt; line-height: 1.2"; >
# Yi_Yang, yy3089
# </span>
# </i>

# %% [markdown]
# ### Submission
# 1. File > Print Preview > Save as PDF...
# 2. Upload .pdf and .ipynb to GradeScope
#
# **This assignment is due October 22, 11:59 pm EDT**
#
#
# ### Collaboration
# - You may use any information you get in TA or Prof. Ferguson's office hours, from lectures or from recitations.
# - You may use information that you find on the web.
# - You are NOT allowed to collaborate with other students outside of office hours.

# %% [markdown]
# ## Part 1: Written & SQL
#
# ### Written
# Please keep your answers brief.

# %% [markdown]
# 1. Codd's Fourth Rule states that: The data base description is represented at the logical level in the same way as ordinary data, so that authorized users can apply the same relational language to its interrogation as they apply to the regular data. In two sentences please explain this rule and why it is so important.
#
# Metadata stored in the data dictionary should obey all the characteristics of a database and it should have correct up to date data. We should be able to access these metadata by using same query language that we use to access the database.
#
# https://www.tutorialcup.com/dbms/codds-rule.htm#Active_Online_Catalog

# %% [markdown]
# 2. Give 3 examples of what would be stored in a database catalog.
#
# base tables, views, indexes

# %% [markdown]
# 3. What is the SQL database catalog called?
#
# INFORMATION_SCHEMA

# %% [markdown]
# 4. What is the overall goal of indices in SQL?
#
# An index contains keys built from one or more columns in the table or view. These keys are stored in a structure (B-tree) that enables SQL Server to find the row or rows associated with the key values quickly and efficiently. Clustered indexes sort and store the data rows in the table or view based on their key values.
#
# https://docs.microsoft.com/en-us/sql/relational-databases/indexes/clustered-and-nonclustered-indexes-described?view=sql-server-ver15

# %% [markdown]
# 5. What are the differences between a primary key and a unique index?
#
# Primary key will not accept NULL values whereas Unique key can accept NULL values. A table can have only primary key whereas there can be multiple unique key on a table. A Clustered index is automatically created when a primary key is defined whereas Unique key generates the non-clustered index.
#
# https://www.geeksforgeeks.org/difference-between-primary-key-and-unique-key/

# %% [markdown]
# 6. Which SELECT statement is more efficient? Why?
#
# - <code> SELECT playerID,birthState,nameLast,nameFirst FROM people
# where birthCountry = 'USA' and nameFirst = 'John' and playerID in (select playerID from collegeplaying where schoolID = 'Fordham'); </code>
#
#
# - <code> SELECT playerID,birthState,nameLast,nameFirst FROM people NATURAL JOIN collegeplaying
# where birthCountry = 'USA' and nameFirst = 'John' and schoolID = 'Fordham' group by playerID,birthState,nameLast,nameFirst; </code>
#
# HINT: SQL uses a query optimizer so you can't just run both of these and see which one performs faster.
#
# I think  the second one is better because in the first query we have to go through all two tables, while in the second query we only have to go through one joined table.

# %% [markdown]
# 7. The create.sql file provided in the zip folder makes a schema and some tables that mimics metadata tables. Note there is the sytax "ON DELETE CASCADE" after the foreign key creation. What does this mean? Why do we want to specify CASCADE for the metadata tables? What does "ON DELETE RESTRICT" mean and when would we generally want to use this?
#
# CASCADE means that the child data is either deleted or updated when the parent data is deleted or updated. ON DELETE CASCADE means that if a record in the parent table is deleted, then the corresponding records in the child table will automatically be deleted.

# %% [markdown]
# ### SQL

# %%
# %load_ext sql
# %sql mysql+pymysql://root:dbuserdbuser@localhost/lahmansbaseballdb

# %% [markdown]
# #### 1. Initials
#
# - Find the ```initials, firstName, lastName```, for every player from the people table.
#
# - You need to return 10 rows.
#
# - Sort by the nameFirst, nameLast ascending.
#
# - Note: Even for those players with two last names, just return the first letter of their first last name
#
# <u>Answer:</u>

# %%
# %%sql
# select concat(ifnull(substr(nameFirst,1,1),'_'), ifnull(substr(nameLast,1,1),'_')) as initials,
# ifnull(nameFirst, '____') as firstName,
# nameLast as lastName
# from lahmansbaseballdb.people
# order by firstName, lastName
# limit 10
# Out:
#  * mysql+pymysql://root:***@localhost/lahmansbaseballdb
# 10 rows affected.
# [('_B', '____', 'Boland'),
#  ('_B', '____', 'Booth'),
#  ('_C', '____', 'Carroll'),
#  ('_E', '____', 'Edwards'),
#  ('_E', '____', 'Evans'),
#  ('_F', '____', 'Franklin'),
#  ('_G', '____', 'Gavern'),
#  ('_H', '____', 'Harrison'),
#  ('_H', '____', 'Hellings'),
#  ('_H', '____', 'Higby')]

# %% [markdown]
# ## Question 1a): Games Per Player using GROUP BY
#
# - Find the ```yearID, lgID, games_per_player```, for every year and league from the appearances table.
#
# - Use a function to round down the games_per_player
#
# - You need to return 10 rows.
#
# - You must use `group by` in this query.
#
# <u>Answer:</u>

# %%
# %%sql
# SELECT yearID, lgID, round(sum(G_all)/count(distinct playerID)) as games_per_player FROM lahmansbaseballdb.appearances
# group by yearID, lgID
# limit 10
# Out:
#  * mysql+pymysql://root:***@localhost/lahmansbaseballdb
# 10 rows affected.
# [(1871, 'NA', Decimal('20')),
#  (1872, 'NA', Decimal('22')),
#  (1873, 'NA', Decimal('30')),
#  (1874, 'NA', Decimal('35')),
#  (1875, 'NA', Decimal('33')),
#  (1876, 'NL', Decimal('39')),
#  (1877, 'NL', Decimal('35')),
#  (1878, 'NL', Decimal('43')),
#  (1879, 'NL', Decimal('49')),
#  (1880, 'NL', Decimal('48'))]

# %% [markdown]
# ## Part 2: CSVCatalog Tests
#
# Once you have tested everything successfuly in python, execute your tests one more time in jupyter notebook to show the expected output. You will need to restart your kernel after saving your python files so that jupyter will use the most recent version of your work.
#
# You may need to drop tables before executing your tests one last time so you don't run into integrity errors

# %%
import unit_test_catalog as cat # This notebook should be in the same directory as your project

# %%
cat.create_table_test()
# Out:
# Running save core definition
# Q =  insert into csvtables values(%s, %s)
# Running load core definition
# Q =  select * from csvtables where table_name = 'test_table'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'test_table'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'test_table' group by index_name, table_name, type, column_name, index_order order by index_order
# Table =  {
#   "table_name": "test_table",
#   "file_name": "./Appearances.csv"
# }

# %%
cat.drop_table_test()
# Out:
# Q =  DELETE FROM csvtables WHERE table_name = 'test_table'
# Table 'test_table' was dropped
# Drop test_table

# %%
cat.create_table_test()
# Out:
# Running save core definition
# Q =  insert into csvtables values(%s, %s)
# Running load core definition
# Q =  select * from csvtables where table_name = 'test_table'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'test_table'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'test_table' group by index_name, table_name, type, column_name, index_order order by index_order
# Table =  {
#   "table_name": "test_table",
#   "file_name": "./Appearances.csv"
# }

# %%
cat.add_column_test()
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'test_table'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'test_table'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'test_table' group by index_name, table_name, type, column_name, index_order order by index_order
# Q =  insert into csvcolumns values(%s, %s, %s, %s)

# %%
try:
    cat.column_name_failure_test()  # This will throw an error
except ValueError as e:
    print(e)
# Out:
# issue!!
# You must have a column name!!

# %%
try:
    cat.column_type_failure_test()  # This will throw an error
except ValueError as e:
    print(e)
# Out:
# Issue!
# That column type is not accepted. Please try again.

# %%
try:
    cat.column_not_null_failure_test()  # This will throw an error
except ValueError as e:
    print(e)
# Out:
# issue!
# The not_null column must be either True or False! Please try again.

# %%
cat.add_index_test()
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'test_table'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'test_table'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'test_table' group by index_name, table_name, type, column_name, index_order order by index_order
# Q =  insert into csvindexes (table_name, column_name, type, index_name, index_order)  values(%s, %s, %s, %s, %s)

# %%
cat.col_drop_test()
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'test_table'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'test_table'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'test_table' group by index_name, table_name, type, column_name, index_order order by index_order
# Q =  delete from csvcolumns where table_name = 'test_table' and column_name = 'test_column'
# Column 'test_column' has been dropped!

# %%
cat.index_drop_test()
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'test_table'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'test_table'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'test_table' group by index_name, table_name, type, column_name, index_order order by index_order
# Running drop index
# Q =  delete from csvindexes where table_name = 'test_table' and index_name = 'test_index'

# %%
cat.describe_table_test()
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'test_table'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'test_table'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'test_table' group by index_name, table_name, type, column_name, index_order order by index_order
# DESCRIBE test_table =
#  {
#   "table_name": "test_table",
#   "file_name": "./Appearances.csv"
# }

# %%
cat.drop_table_test()
# Out:
# Q =  DELETE FROM csvtables WHERE table_name = 'test_table'
# Table 'test_table' was dropped
# Drop test_table

# %% [markdown]
# ## Part 3: CSVTable Tests
#
# In the event that the data sent is too large, jupyter notebook will throw a warning and not print any output. This will happen when you try to retrieve an entire table. Don't worry about getting the output if this happens.
#
# Additonally, the table formatting will get messed up if the columns makes the output too wide. In your tests make sure you project fields so that your outputs are legible.

# %%
import unit_test_csv_table as tab

# %%
# Drop the tables if you already made them when testing
tab.drop_tables_for_prep()
# Out:
# Q =  DELETE FROM csvtables WHERE table_name = 'people'
# Table 'people' was dropped
# Q =  DELETE FROM csvtables WHERE table_name = 'batting'
# Table 'batting' was dropped
# Q =  DELETE FROM csvtables WHERE table_name = 'appearances'
# Table 'appearances' was dropped

# %%
tab.create_lahman_tables()
# Out:
# Running save core definition
# Q =  insert into csvtables values(%s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Running save core definition
# Q =  insert into csvtables values(%s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Running save core definition
# Q =  insert into csvtables values(%s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)
# Q =  insert into csvcolumns values(%s, %s, %s, %s)

# %%
try:
    tab.update_people_columns()
except Exception as e:
    print(e)
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'people'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'people'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'people' group by index_name, table_name, type, column_name, index_order order by index_order
# DataTableException: code: -200 , message: Updated not implemented

# %%
try:
    tab.update_appearances_columns()
except Exception as e:
    print(e)
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'appearances'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'appearances'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'appearances' group by index_name, table_name, type, column_name, index_order order by index_order
# DataTableException: code: -200 , message: Updated not implemented

# %%
try:
    tab.update_batting_columns()
except Exception as e:
    print(e)
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'batting'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'batting'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'batting' group by index_name, table_name, type, column_name, index_order order by index_order
# DataTableException: code: -200 , message: Updated not implemented

# %%
tab.add_index_definitions()
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'people'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'people'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'people' group by index_name, table_name, type, column_name, index_order order by index_order
# Q =  insert into csvindexes (table_name, column_name, type, index_name, index_order)  values(%s, %s, %s, %s, %s)
# Running load core definition
# Q =  select * from csvtables where table_name = 'batting'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'batting'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'batting' group by index_name, table_name, type, column_name, index_order order by index_order
# Q =  insert into csvindexes (table_name, column_name, type, index_name, index_order)  values(%s, %s, %s, %s, %s)
# Running load core definition
# Q =  select * from csvtables where table_name = 'appearances'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'appearances'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'appearances' group by index_name, table_name, type, column_name, index_order order by index_order
# Q =  insert into csvindexes (table_name, column_name, type, index_name, index_order)  values(%s, %s, %s, %s, %s)

# %%
tab.test_load_info()
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'people'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'people'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'people' group by index_name, table_name, type, column_name, index_order order by index_order
# ./People.csv

# %%
tab.test_get_col_names()
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'people'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'people'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'people' group by index_name, table_name, type, column_name, index_order order by index_order
# ['bats', 'bbrefID', 'birthCity', 'birthCountry', 'birthDay', 'birthMonth', 'birthState', 'birthYear', 'deathCity', 'deathCountry', 'deathDay', 'deathMonth', 'deathState', 'deathYear', 'debut', 'finalGame', 'height', 'nameFirst', 'nameGiven', 'nameLast', 'playerID', 'retroID', 'throws', 'weight']

# %%
tab.add_other_indexes()
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'people'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'people'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'people' group by index_name, table_name, type, column_name, index_order order by index_order
# Q =  insert into csvindexes (table_name, column_name, type, index_name, index_order)  values(%s, %s, %s, %s, %s)
# Q =  insert into csvindexes (table_name, column_name, type, index_name, index_order)  values(%s, %s, %s, %s, %s)
# Running load core definition
# Q =  select * from csvtables where table_name = 'appearances'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'appearances'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'appearances' group by index_name, table_name, type, column_name, index_order order by index_order
# Q =  insert into csvindexes (table_name, column_name, type, index_name, index_order)  values(%s, %s, %s, %s, %s)

# %%
# This should throw an error
# Make sure it works properly when you run it in pycharm though!
tab.load_test()
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'batting'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'batting'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'batting' group by index_name, table_name, type, column_name, index_order order by index_order
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# Might throw an error depending on table size
# Make sure it works properly when you run it in pycharm though!
tab.dumb_join_test()
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'people'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'people'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'people' group by index_name, table_name, type, column_name, index_order order by index_order
# Running load core definition
# Q =  select * from csvtables where table_name = 'appearances'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'appearances'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'appearances' group by index_name, table_name, type, column_name, index_order order by index_order
# Processed 10 left rows.
# Processed 20 left rows.
# Processed 30 left rows.
# Processed 40 left rows.
# Processed 50 left rows.
# Processed 60 left rows.
# Processed 70 left rows.
# Processed 80 left rows.
# Processed 90 left rows.
# Processed 100 left rows.
# Processed 110 left rows.
# Processed 120 left rows.
# Processed 130 left rows.
# Processed 140 left rows.
# Processed 150 left rows.
# Processed 160 left rows.
# Processed 170 left rows.
# Processed 180 left rows.
# Processed 190 left rows.
# Processed 200 left rows.
# Processed 210 left rows.
# Processed 220 left rows.
# Processed 230 left rows.
# Processed 240 left rows.
# Processed 250 left rows.
# Processed 260 left rows.
# Processed 270 left rows.
# Processed 280 left rows.
# Processed 290 left rows.
# Processed 300 left rows.
# Processed 310 left rows.
# Processed 320 left rows.
# Processed 330 left rows.
# Processed 340 left rows.
# Processed 350 left rows.
# Processed 360 left rows.
# Processed 370 left rows.
# Processed 380 left rows.
# Processed 390 left rows.
# Processed 400 left rows.
# Processed 410 left rows.
# Processed 420 left rows.
# Processed 430 left rows.
# Processed 440 left rows.
# Processed 450 left rows.
# Processed 460 left rows.
# Processed 470 left rows.
# Processed 480 left rows.
# Processed 490 left rows.
# Processed 500 left rows.
# Processed 510 left rows.
# Processed 520 left rows.
# Processed 530 left rows.
# Processed 540 left rows.
# Processed 550 left rows.
# Processed 560 left rows.
# Processed 570 left rows.
# Processed 580 left rows.
# Processed 590 left rows.
# Processed 600 left rows.
# Processed 610 left rows.
# Processed 620 left rows.
# Processed 630 left rows.
# Processed 640 left rows.
# Processed 650 left rows.
# Processed 660 left rows.
# Processed 670 left rows.
# Processed 680 left rows.
# Processed 690 left rows.
# Processed 700 left rows.
# Processed 710 left rows.
# Processed 720 left rows.
# Processed 730 left rows.
# Processed 740 left rows.
# Processed 750 left rows.
# Processed 760 left rows.
# Processed 770 left rows.
# Processed 780 left rows.
# Processed 790 left rows.
# Processed 800 left rows.
# Processed 810 left rows.
# Processed 820 left rows.
# Processed 830 left rows.
# Processed 840 left rows.
# Processed 850 left rows.
# Processed 860 left rows.
# Processed 870 left rows.
# Processed 880 left rows.
# Processed 890 left rows.
# Processed 900 left rows.
# Processed 910 left rows.
# Processed 920 left rows.
# Processed 930 left rows.
# Processed 940 left rows.
# Processed 950 left rows.
# Processed 960 left rows.
# Processed 970 left rows.
# Processed 980 left rows.
# Processed 990 left rows.
# Processed 1000 left rows.
# Processed 1010 left rows.
# Processed 1020 left rows.
# Processed 1030 left rows.
# Processed 1040 left rows.
# Processed 1050 left rows.
# Processed 1060 left rows.
# Processed 1070 left rows.
# Processed 1080 left rows.
# Processed 1090 left rows.
# Processed 1100 left rows.
# Processed 1110 left rows.
# Processed 1120 left rows.
# Processed 1130 left rows.
# Processed 1140 left rows.
# Processed 1150 left rows.
# Processed 1160 left rows.
# Processed 1170 left rows.
# Processed 1180 left rows.
# Processed 1190 left rows.
# Processed 1200 left rows.
# Processed 1210 left rows.
# Processed 1220 left rows.
# Processed 1230 left rows.
# Processed 1240 left rows.
# Processed 1250 left rows.
# Processed 1260 left rows.
# Processed 1270 left rows.
# Processed 1280 left rows.
# Processed 1290 left rows.
# Processed 1300 left rows.
# Processed 1310 left rows.
# Processed 1320 left rows.
# Processed 1330 left rows.
# Processed 1340 left rows.
# Processed 1350 left rows.
# Processed 1360 left rows.
# Processed 1370 left rows.
# Processed 1380 left rows.
# Processed 1390 left rows.
# Processed 1400 left rows.
# Processed 1410 left rows.
# Processed 1420 left rows.
# Processed 1430 left rows.
# Processed 1440 left rows.
# Processed 1450 left rows.
# Processed 1460 left rows.
# Processed 1470 left rows.
# Processed 1480 left rows.
# Processed 1490 left rows.
# Processed 1500 left rows.
# Processed 1510 left rows.
# Processed 1520 left rows.
# Processed 1530 left rows.
# Processed 1540 left rows.
# Processed 1550 left rows.
# Processed 1560 left rows.
# Processed 1570 left rows.
# Processed 1580 left rows.
# Processed 1590 left rows.
# Processed 1600 left rows.
# Processed 1610 left rows.
# Processed 1620 left rows.
# Processed 1630 left rows.
# Processed 1640 left rows.
# Processed 1650 left rows.
# Processed 1660 left rows.
# Processed 1670 left rows.
# Processed 1680 left rows.
# Processed 1690 left rows.
# Processed 1700 left rows.
# Processed 1710 left rows.
# Processed 1720 left rows.
# Processed 1730 left rows.
# Processed 1740 left rows.
# Processed 1750 left rows.
# Processed 1760 left rows.
# Processed 1770 left rows.
# Processed 1780 left rows.
# Processed 1790 left rows.
# Processed 1800 left rows.
# Processed 1810 left rows.
# Processed 1820 left rows.
# Processed 1830 left rows.
# Processed 1840 left rows.
# Processed 1850 left rows.
# Processed 1860 left rows.
# Processed 1870 left rows.
# Processed 1880 left rows.
# Processed 1890 left rows.
# Processed 1900 left rows.
# Processed 1910 left rows.
# Processed 1920 left rows.
# Processed 1930 left rows.
# Processed 1940 left rows.
# Processed 1950 left rows.
# Processed 1960 left rows.
# Processed 1970 left rows.
# Processed 1980 left rows.
# Processed 1990 left rows.
# Processed 2000 left rows.
# Processed 2010 left rows.
# Processed 2020 left rows.
# Processed 2030 left rows.
# Processed 2040 left rows.
# Processed 2050 left rows.
# Processed 2060 left rows.
# Processed 2070 left rows.
# Processed 2080 left rows.
# Processed 2090 left rows.
# Processed 2100 left rows.
# Processed 2110 left rows.
# Processed 2120 left rows.
# Processed 2130 left rows.
# Processed 2140 left rows.
# Processed 2150 left rows.
# Processed 2160 left rows.
# Processed 2170 left rows.
# Processed 2180 left rows.
# Processed 2190 left rows.
# Processed 2200 left rows.
# Processed 2210 left rows.
# Processed 2220 left rows.
# Processed 2230 left rows.
# Processed 2240 left rows.
# Processed 2250 left rows.
# Processed 2260 left rows.
# Processed 2270 left rows.
# Processed 2280 left rows.
# Processed 2290 left rows.
# Processed 2300 left rows.
# Processed 2310 left rows.
# Processed 2320 left rows.
# Processed 2330 left rows.
# Processed 2340 left rows.
# Processed 2350 left rows.
# Processed 2360 left rows.
# Processed 2370 left rows.
# Processed 2380 left rows.
# Processed 2390 left rows.
# Processed 2400 left rows.
# Processed 2410 left rows.
# Processed 2420 left rows.
# Processed 2430 left rows.
# Processed 2440 left rows.
# Processed 2450 left rows.
# Processed 2460 left rows.
# Processed 2470 left rows.
# Processed 2480 left rows.
# Processed 2490 left rows.
# Processed 2500 left rows.
# Processed 2510 left rows.
# Processed 2520 left rows.
# Processed 2530 left rows.
# Processed 2540 left rows.
# Processed 2550 left rows.
# Processed 2560 left rows.
# Processed 2570 left rows.
# Processed 2580 left rows.
# Processed 2590 left rows.
# Processed 2600 left rows.
# Processed 2610 left rows.
# Processed 2620 left rows.
# Processed 2630 left rows.
# Processed 2640 left rows.
# Processed 2650 left rows.
# Processed 2660 left rows.
# Processed 2670 left rows.
# Processed 2680 left rows.
# Processed 2690 left rows.
# Processed 2700 left rows.
# Processed 2710 left rows.
# Processed 2720 left rows.
# Processed 2730 left rows.
# Processed 2740 left rows.
# Processed 2750 left rows.
# Processed 2760 left rows.
# Processed 2770 left rows.
# Processed 2780 left rows.
# Processed 2790 left rows.
# Processed 2800 left rows.
# Processed 2810 left rows.
# Processed 2820 left rows.
# Processed 2830 left rows.
# Processed 2840 left rows.
# Processed 2850 left rows.
# Processed 2860 left rows.
# Processed 2870 left rows.
# Processed 2880 left rows.
# Processed 2890 left rows.
# Processed 2900 left rows.
# Processed 2910 left rows.
# Processed 2920 left rows.
# Processed 2930 left rows.
# Processed 2940 left rows.
# Processed 2950 left rows.
# Processed 2960 left rows.
# Processed 2970 left rows.
# Processed 2980 left rows.
# Processed 2990 left rows.
# Processed 3000 left rows.
# Processed 3010 left rows.
# Processed 3020 left rows.
# Processed 3030 left rows.
# Processed 3040 left rows.
# Processed 3050 left rows.
# Processed 3060 left rows.
# Processed 3070 left rows.
# Processed 3080 left rows.
# Processed 3090 left rows.
# Processed 3100 left rows.
# Processed 3110 left rows.
# Processed 3120 left rows.
# Processed 3130 left rows.
# Processed 3140 left rows.
# Processed 3150 left rows.
# Processed 3160 left rows.
# Processed 3170 left rows.
# Processed 3180 left rows.
# Processed 3190 left rows.
# Processed 3200 left rows.
# Processed 3210 left rows.
# Processed 3220 left rows.
# Processed 3230 left rows.
# Processed 3240 left rows.
# Processed 3250 left rows.
# Processed 3260 left rows.
# Processed 3270 left rows.
# Processed 3280 left rows.
# Processed 3290 left rows.
# Processed 3300 left rows.
# Processed 3310 left rows.
# Processed 3320 left rows.
# Processed 3330 left rows.
# Processed 3340 left rows.
# Processed 3350 left rows.
# Processed 3360 left rows.
# Processed 3370 left rows.
# Processed 3380 left rows.
# Processed 3390 left rows.
# Processed 3400 left rows.
# Processed 3410 left rows.
# Processed 3420 left rows.
# Processed 3430 left rows.
# Processed 3440 left rows.
# Processed 3450 left rows.
# Processed 3460 left rows.
# Processed 3470 left rows.
# Processed 3480 left rows.
# Processed 3490 left rows.
# Processed 3500 left rows.
# Processed 3510 left rows.
# Processed 3520 left rows.
# Processed 3530 left rows.
# Processed 3540 left rows.
# Processed 3550 left rows.
# Processed 3560 left rows.
# Processed 3570 left rows.
# Processed 3580 left rows.
# Processed 3590 left rows.
# Processed 3600 left rows.
# Processed 3610 left rows.
# Processed 3620 left rows.
# Processed 3630 left rows.
# Processed 3640 left rows.
# Processed 3650 left rows.
# Processed 3660 left rows.
# Processed 3670 left rows.
# Processed 3680 left rows.
# Processed 3690 left rows.
# Processed 3700 left rows.
# Processed 3710 left rows.
# Processed 3720 left rows.
# Processed 3730 left rows.
# Processed 3740 left rows.
# Processed 3750 left rows.
# Processed 3760 left rows.
# Processed 3770 left rows.
# Processed 3780 left rows.
# Processed 3790 left rows.
# Processed 3800 left rows.
# Processed 3810 left rows.
# Processed 3820 left rows.
# Processed 3830 left rows.
# Processed 3840 left rows.
# Processed 3850 left rows.
# Processed 3860 left rows.
# Processed 3870 left rows.
# Processed 3880 left rows.
# Processed 3890 left rows.
# Processed 3900 left rows.
# Processed 3910 left rows.
# Processed 3920 left rows.
# Processed 3930 left rows.
# Processed 3940 left rows.
# Processed 3950 left rows.
# Processed 3960 left rows.
# Processed 3970 left rows.
# Processed 3980 left rows.
# Processed 3990 left rows.
# Processed 4000 left rows.
# Processed 4010 left rows.
# Processed 4020 left rows.
# Processed 4030 left rows.
# Processed 4040 left rows.
# Processed 4050 left rows.
# Processed 4060 left rows.
# Processed 4070 left rows.
# Processed 4080 left rows.
# Processed 4090 left rows.
# Processed 4100 left rows.
# Processed 4110 left rows.
# Processed 4120 left rows.
# Processed 4130 left rows.
# Processed 4140 left rows.
# Processed 4150 left rows.
# Processed 4160 left rows.
# Processed 4170 left rows.
# Processed 4180 left rows.
# Processed 4190 left rows.
# Processed 4200 left rows.
# Processed 4210 left rows.
# Processed 4220 left rows.
# Processed 4230 left rows.
# Processed 4240 left rows.
# Processed 4250 left rows.
# Processed 4260 left rows.
# Processed 4270 left rows.
# Processed 4280 left rows.
# Processed 4290 left rows.
# Processed 4300 left rows.
# Processed 4310 left rows.
# Processed 4320 left rows.
# Processed 4330 left rows.
# Processed 4340 left rows.
# Processed 4350 left rows.
# Processed 4360 left rows.
# Processed 4370 left rows.
# Processed 4380 left rows.
# Processed 4390 left rows.
# Processed 4400 left rows.
# Processed 4410 left rows.
# Processed 4420 left rows.
# Processed 4430 left rows.
# Processed 4440 left rows.
# Processed 4450 left rows.
# Processed 4460 left rows.
# Processed 4470 left rows.
# Processed 4480 left rows.
# Processed 4490 left rows.
# Processed 4500 left rows.
# Processed 4510 left rows.
# Processed 4520 left rows.
# Processed 4530 left rows.
# Processed 4540 left rows.
# Processed 4550 left rows.
# Processed 4560 left rows.
# Processed 4570 left rows.
# Processed 4580 left rows.
# Processed 4590 left rows.
# Processed 4600 left rows.
# Processed 4610 left rows.
# Processed 4620 left rows.
# Processed 4630 left rows.
# Processed 4640 left rows.
# Processed 4650 left rows.
# Processed 4660 left rows.
# Processed 4670 left rows.
# Processed 4680 left rows.
# Processed 4690 left rows.
# Processed 4700 left rows.
# Processed 4710 left rows.
# Processed 4720 left rows.
# Processed 4730 left rows.
# Processed 4740 left rows.
# Processed 4750 left rows.
# Processed 4760 left rows.
# Processed 4770 left rows.
# Processed 4780 left rows.
# Processed 4790 left rows.
# Processed 4800 left rows.
# Processed 4810 left rows.
# Processed 4820 left rows.
# Processed 4830 left rows.
# Processed 4840 left rows.
# Processed 4850 left rows.
# Processed 4860 left rows.
# Processed 4870 left rows.
# Processed 4880 left rows.
# Processed 4890 left rows.
# Processed 4900 left rows.
# Processed 4910 left rows.
# Processed 4920 left rows.
# Processed 4930 left rows.
# Processed 4940 left rows.
# Processed 4950 left rows.
# Processed 4960 left rows.
# Processed 4970 left rows.
# Processed 4980 left rows.
# Processed 4990 left rows.
# Processed 5000 left rows.
# Processed 5010 left rows.
# Processed 5020 left rows.
# Processed 5030 left rows.
# Processed 5040 left rows.
# Processed 5050 left rows.
# Processed 5060 left rows.
# Processed 5070 left rows.
# Processed 5080 left rows.
# Processed 5090 left rows.
# Processed 5100 left rows.
# Processed 5110 left rows.
# Processed 5120 left rows.
# Processed 5130 left rows.
# Processed 5140 left rows.
# Processed 5150 left rows.
# Processed 5160 left rows.
# Processed 5170 left rows.
# Processed 5180 left rows.
# Processed 5190 left rows.
# Processed 5200 left rows.
# Processed 5210 left rows.
# Processed 5220 left rows.
# Processed 5230 left rows.
# Processed 5240 left rows.
# Processed 5250 left rows.
# Processed 5260 left rows.
# Processed 5270 left rows.
# Processed 5280 left rows.
# Processed 5290 left rows.
# Processed 5300 left rows.
# Processed 5310 left rows.
# Processed 5320 left rows.
# Processed 5330 left rows.
# Processed 5340 left rows.
# Processed 5350 left rows.
# Processed 5360 left rows.
# Processed 5370 left rows.
# Processed 5380 left rows.
# Processed 5390 left rows.
# Processed 5400 left rows.
# Processed 5410 left rows.
# Processed 5420 left rows.
# Processed 5430 left rows.
# Processed 5440 left rows.
# Processed 5450 left rows.
# Processed 5460 left rows.
# Processed 5470 left rows.
# Processed 5480 left rows.
# Processed 5490 left rows.
# Processed 5500 left rows.
# Processed 5510 left rows.
# Processed 5520 left rows.
# Processed 5530 left rows.
# Processed 5540 left rows.
# Processed 5550 left rows.
# Processed 5560 left rows.
# Processed 5570 left rows.
# Processed 5580 left rows.
# Processed 5590 left rows.
# Processed 5600 left rows.
# Processed 5610 left rows.
# Processed 5620 left rows.
# Processed 5630 left rows.
# Processed 5640 left rows.
# Processed 5650 left rows.
# Processed 5660 left rows.
# Processed 5670 left rows.
# Processed 5680 left rows.
# Processed 5690 left rows.
# Processed 5700 left rows.
# Processed 5710 left rows.
# Processed 5720 left rows.
# Processed 5730 left rows.
# Processed 5740 left rows.
# Processed 5750 left rows.
# Processed 5760 left rows.
# Processed 5770 left rows.
# Processed 5780 left rows.
# Processed 5790 left rows.
# Processed 5800 left rows.
# Processed 5810 left rows.
# Processed 5820 left rows.
# Processed 5830 left rows.
# Processed 5840 left rows.
# Processed 5850 left rows.
# Processed 5860 left rows.
# Processed 5870 left rows.
# Processed 5880 left rows.
# Processed 5890 left rows.
# Processed 5900 left rows.
# Processed 5910 left rows.
# Processed 5920 left rows.
# Processed 5930 left rows.
# Processed 5940 left rows.
# Processed 5950 left rows.
# Processed 5960 left rows.
# Processed 5970 left rows.
# Processed 5980 left rows.
# Processed 5990 left rows.
# Processed 6000 left rows.
# Processed 6010 left rows.
# Processed 6020 left rows.
# Processed 6030 left rows.
# Processed 6040 left rows.
# Processed 6050 left rows.
# Processed 6060 left rows.
# Processed 6070 left rows.
# Processed 6080 left rows.
# Processed 6090 left rows.
# Processed 6100 left rows.
# Processed 6110 left rows.
# Processed 6120 left rows.
# Processed 6130 left rows.
# Processed 6140 left rows.
# Processed 6150 left rows.
# Processed 6160 left rows.
# Processed 6170 left rows.
# Processed 6180 left rows.
# Processed 6190 left rows.
# Processed 6200 left rows.
# Processed 6210 left rows.
# Processed 6220 left rows.
# Processed 6230 left rows.
# Processed 6240 left rows.
# Processed 6250 left rows.
# Processed 6260 left rows.
# Processed 6270 left rows.
# Processed 6280 left rows.
# Processed 6290 left rows.
# Processed 6300 left rows.
# Processed 6310 left rows.
# Processed 6320 left rows.
# Processed 6330 left rows.
# Processed 6340 left rows.
# Processed 6350 left rows.
# Processed 6360 left rows.
# Processed 6370 left rows.
# Processed 6380 left rows.
# Processed 6390 left rows.
# Processed 6400 left rows.
# Processed 6410 left rows.
# Processed 6420 left rows.
# Processed 6430 left rows.
# Processed 6440 left rows.
# Processed 6450 left rows.
# Processed 6460 left rows.
# Processed 6470 left rows.
# Processed 6480 left rows.
# Processed 6490 left rows.
# Processed 6500 left rows.
# Processed 6510 left rows.
# Processed 6520 left rows.
# Processed 6530 left rows.
# Processed 6540 left rows.
# Processed 6550 left rows.
# Processed 6560 left rows.
# Processed 6570 left rows.
# Processed 6580 left rows.
# Processed 6590 left rows.
# Processed 6600 left rows.
# Processed 6610 left rows.
# Processed 6620 left rows.
# Processed 6630 left rows.
# Processed 6640 left rows.
# Processed 6650 left rows.
# Processed 6660 left rows.
# Processed 6670 left rows.
# Processed 6680 left rows.
# Processed 6690 left rows.
# Processed 6700 left rows.
# Processed 6710 left rows.
# Processed 6720 left rows.
# Processed 6730 left rows.
# Processed 6740 left rows.
# Processed 6750 left rows.
# Processed 6760 left rows.
# Processed 6770 left rows.
# Processed 6780 left rows.
# Processed 6790 left rows.
# Processed 6800 left rows.
# Processed 6810 left rows.
# Processed 6820 left rows.
# Processed 6830 left rows.
# Processed 6840 left rows.
# Processed 6850 left rows.
# Processed 6860 left rows.
# Processed 6870 left rows.
# Processed 6880 left rows.
# Processed 6890 left rows.
# Processed 6900 left rows.
# Processed 6910 left rows.
# Processed 6920 left rows.
# Processed 6930 left rows.
# Processed 6940 left rows.
# Processed 6950 left rows.
# Processed 6960 left rows.
# Processed 6970 left rows.
# Processed 6980 left rows.
# Processed 6990 left rows.
# Processed 7000 left rows.
# Processed 7010 left rows.
# Processed 7020 left rows.
# Processed 7030 left rows.
# Processed 7040 left rows.
# Processed 7050 left rows.
# Processed 7060 left rows.
# Processed 7070 left rows.
# Processed 7080 left rows.
# Processed 7090 left rows.
# Processed 7100 left rows.
# Processed 7110 left rows.
# Processed 7120 left rows.
# Processed 7130 left rows.
# Processed 7140 left rows.
# Processed 7150 left rows.
# Processed 7160 left rows.
# Processed 7170 left rows.
# Processed 7180 left rows.
# Processed 7190 left rows.
# Processed 7200 left rows.
# Processed 7210 left rows.
# Processed 7220 left rows.
# Processed 7230 left rows.
# Processed 7240 left rows.
# Processed 7250 left rows.
# Processed 7260 left rows.
# Processed 7270 left rows.
# Processed 7280 left rows.
# Processed 7290 left rows.
# Processed 7300 left rows.
# Processed 7310 left rows.
# Processed 7320 left rows.
# Processed 7330 left rows.
# Processed 7340 left rows.
# Processed 7350 left rows.
# Processed 7360 left rows.
# Processed 7370 left rows.
# Processed 7380 left rows.
# Processed 7390 left rows.
# Processed 7400 left rows.
# Processed 7410 left rows.
# Processed 7420 left rows.
# Processed 7430 left rows.
# Processed 7440 left rows.
# Processed 7450 left rows.
# Processed 7460 left rows.
# Processed 7470 left rows.
# Processed 7480 left rows.
# Processed 7490 left rows.
# Processed 7500 left rows.
# Processed 7510 left rows.
# Processed 7520 left rows.
# Processed 7530 left rows.
# Processed 7540 left rows.
# Processed 7550 left rows.
# Processed 7560 left rows.
# Processed 7570 left rows.
# Processed 7580 left rows.
# Processed 7590 left rows.
# Processed 7600 left rows.
# Processed 7610 left rows.
# Processed 7620 left rows.
# Processed 7630 left rows.
# Processed 7640 left rows.
# Processed 7650 left rows.
# Processed 7660 left rows.
# Processed 7670 left rows.
# Processed 7680 left rows.
# Processed 7690 left rows.
# Processed 7700 left rows.
# Processed 7710 left rows.
# Processed 7720 left rows.
# Processed 7730 left rows.
# Processed 7740 left rows.
# Processed 7750 left rows.
# Processed 7760 left rows.
# Processed 7770 left rows.
# Processed 7780 left rows.
# Processed 7790 left rows.
# Processed 7800 left rows.
# Processed 7810 left rows.
# Processed 7820 left rows.
# Processed 7830 left rows.
# Processed 7840 left rows.
# Processed 7850 left rows.
# Processed 7860 left rows.
# Processed 7870 left rows.
# Processed 7880 left rows.
# Processed 7890 left rows.
# Processed 7900 left rows.
# Processed 7910 left rows.
# Processed 7920 left rows.
# Processed 7930 left rows.
# Processed 7940 left rows.
# Processed 7950 left rows.
# Processed 7960 left rows.
# Processed 7970 left rows.
# Processed 7980 left rows.
# Processed 7990 left rows.
# Processed 8000 left rows.
# Processed 8010 left rows.
# Processed 8020 left rows.
# Processed 8030 left rows.
# Processed 8040 left rows.
# Processed 8050 left rows.
# Processed 8060 left rows.
# Processed 8070 left rows.
# Processed 8080 left rows.
# Processed 8090 left rows.
# Processed 8100 left rows.
# Processed 8110 left rows.
# Processed 8120 left rows.
# Processed 8130 left rows.
# Processed 8140 left rows.
# Processed 8150 left rows.
# Processed 8160 left rows.
# Processed 8170 left rows.
# Processed 8180 left rows.
# Processed 8190 left rows.
# Processed 8200 left rows.
# Processed 8210 left rows.
# Processed 8220 left rows.
# Processed 8230 left rows.
# Processed 8240 left rows.
# Processed 8250 left rows.
# Processed 8260 left rows.
# Processed 8270 left rows.
# Processed 8280 left rows.
# Processed 8290 left rows.
# Processed 8300 left rows.
# Processed 8310 left rows.
# Processed 8320 left rows.
# Processed 8330 left rows.
# Processed 8340 left rows.
# Processed 8350 left rows.
# Processed 8360 left rows.
# Processed 8370 left rows.
# Processed 8380 left rows.
# Processed 8390 left rows.
# Processed 8400 left rows.
# Processed 8410 left rows.
# Processed 8420 left rows.
# Processed 8430 left rows.
# Processed 8440 left rows.
# Processed 8450 left rows.
# Processed 8460 left rows.
# Processed 8470 left rows.
# Processed 8480 left rows.
# Processed 8490 left rows.
# Processed 8500 left rows.
# Processed 8510 left rows.
# Processed 8520 left rows.
# Processed 8530 left rows.
# Processed 8540 left rows.
# Processed 8550 left rows.
# Processed 8560 left rows.
# Processed 8570 left rows.
# Processed 8580 left rows.
# Processed 8590 left rows.
# Processed 8600 left rows.
# Processed 8610 left rows.
# Processed 8620 left rows.
# Processed 8630 left rows.
# Processed 8640 left rows.
# Processed 8650 left rows.
# Processed 8660 left rows.
# Processed 8670 left rows.
# Processed 8680 left rows.
# Processed 8690 left rows.
# Processed 8700 left rows.
# Processed 8710 left rows.
# Processed 8720 left rows.
# Processed 8730 left rows.
# Processed 8740 left rows.
# Processed 8750 left rows.
# Processed 8760 left rows.
# Processed 8770 left rows.
# Processed 8780 left rows.
# Processed 8790 left rows.
# Processed 8800 left rows.
# Processed 8810 left rows.
# Processed 8820 left rows.
# Processed 8830 left rows.
# Processed 8840 left rows.
# Processed 8850 left rows.
# Processed 8860 left rows.
# Processed 8870 left rows.
# Processed 8880 left rows.
# Processed 8890 left rows.
# Processed 8900 left rows.
# Processed 8910 left rows.
# Processed 8920 left rows.
# Processed 8930 left rows.
# Processed 8940 left rows.
# Processed 8950 left rows.
# Processed 8960 left rows.
# Processed 8970 left rows.
# Processed 8980 left rows.
# Processed 8990 left rows.
# Processed 9000 left rows.
# Processed 9010 left rows.
# Processed 9020 left rows.
# Processed 9030 left rows.
# Processed 9040 left rows.
# Processed 9050 left rows.
# Processed 9060 left rows.
# Processed 9070 left rows.
# Processed 9080 left rows.
# Processed 9090 left rows.
# Processed 9100 left rows.
# Processed 9110 left rows.
# Processed 9120 left rows.
# Processed 9130 left rows.
# Processed 9140 left rows.
# Processed 9150 left rows.
# Processed 9160 left rows.
# Processed 9170 left rows.
# Processed 9180 left rows.
# Processed 9190 left rows.
# Processed 9200 left rows.
# Processed 9210 left rows.
# Processed 9220 left rows.
# Processed 9230 left rows.
# Processed 9240 left rows.
# Processed 9250 left rows.
# Processed 9260 left rows.
# Processed 9270 left rows.
# Processed 9280 left rows.
# Processed 9290 left rows.
# Processed 9300 left rows.
# Processed 9310 left rows.
# Processed 9320 left rows.
# Processed 9330 left rows.
# Processed 9340 left rows.
# Processed 9350 left rows.
# Processed 9360 left rows.
# Processed 9370 left rows.
# Processed 9380 left rows.
# Processed 9390 left rows.
# Processed 9400 left rows.
# Processed 9410 left rows.
# Processed 9420 left rows.
# Processed 9430 left rows.
# Processed 9440 left rows.
# Processed 9450 left rows.
# Processed 9460 left rows.
# Processed 9470 left rows.
# Processed 9480 left rows.
# Processed 9490 left rows.
# Processed 9500 left rows.
# Processed 9510 left rows.
# Processed 9520 left rows.
# Processed 9530 left rows.
# Processed 9540 left rows.
# Processed 9550 left rows.
# Processed 9560 left rows.
# Processed 9570 left rows.
# Processed 9580 left rows.
# Processed 9590 left rows.
# Processed 9600 left rows.
# Processed 9610 left rows.
# Processed 9620 left rows.
# Processed 9630 left rows.
# Processed 9640 left rows.
# Processed 9650 left rows.
# Processed 9660 left rows.
# Processed 9670 left rows.
# Processed 9680 left rows.
# Processed 9690 left rows.
# Processed 9700 left rows.
# Processed 9710 left rows.
# Processed 9720 left rows.
# Processed 9730 left rows.
# Processed 9740 left rows.
# Processed 9750 left rows.
# Processed 9760 left rows.
# Processed 9770 left rows.
# Processed 9780 left rows.
# Processed 9790 left rows.
# Processed 9800 left rows.
# Processed 9810 left rows.
# Processed 9820 left rows.
# Processed 9830 left rows.
# Processed 9840 left rows.
# Processed 9850 left rows.
# Processed 9860 left rows.
# Processed 9870 left rows.
# Processed 9880 left rows.
# Processed 9890 left rows.
# Processed 9900 left rows.
# Processed 9910 left rows.
# Processed 9920 left rows.
# Processed 9930 left rows.
# Processed 9940 left rows.
# Processed 9950 left rows.
# Processed 9960 left rows.
# Processed 9970 left rows.
# Processed 9980 left rows.
# Processed 9990 left rows.
# Processed 10000 left rows.
# Processed 10010 left rows.
# Processed 10020 left rows.
# Processed 10030 left rows.
# Processed 10040 left rows.
# Processed 10050 left rows.
# Processed 10060 left rows.
# Processed 10070 left rows.
# Processed 10080 left rows.
# Processed 10090 left rows.
# Processed 10100 left rows.
# Processed 10110 left rows.
# Processed 10120 left rows.
# Processed 10130 left rows.
# Processed 10140 left rows.
# Processed 10150 left rows.
# Processed 10160 left rows.
# Processed 10170 left rows.
# Processed 10180 left rows.
# Processed 10190 left rows.
# Processed 10200 left rows.
# Processed 10210 left rows.
# Processed 10220 left rows.
# Processed 10230 left rows.
# Processed 10240 left rows.
# Processed 10250 left rows.
# Processed 10260 left rows.
# Processed 10270 left rows.
# Processed 10280 left rows.
# Processed 10290 left rows.
# Processed 10300 left rows.
# Processed 10310 left rows.
# Processed 10320 left rows.
# Processed 10330 left rows.
# Processed 10340 left rows.
# Processed 10350 left rows.
# Processed 10360 left rows.
# Processed 10370 left rows.
# Processed 10380 left rows.
# Processed 10390 left rows.
# Processed 10400 left rows.
# Processed 10410 left rows.
# Processed 10420 left rows.
# Processed 10430 left rows.
# Processed 10440 left rows.
# Processed 10450 left rows.
# Processed 10460 left rows.
# Processed 10470 left rows.
# Processed 10480 left rows.
# Processed 10490 left rows.
# Processed 10500 left rows.
# Processed 10510 left rows.
# Processed 10520 left rows.
# Processed 10530 left rows.
# Processed 10540 left rows.
# Processed 10550 left rows.
# Processed 10560 left rows.
# Processed 10570 left rows.
# Processed 10580 left rows.
# Processed 10590 left rows.
# Processed 10600 left rows.
# Processed 10610 left rows.
# Processed 10620 left rows.
# Processed 10630 left rows.
# Processed 10640 left rows.
# Processed 10650 left rows.
# Processed 10660 left rows.
# Processed 10670 left rows.
# Processed 10680 left rows.
# Processed 10690 left rows.
# Processed 10700 left rows.
# Processed 10710 left rows.
# Processed 10720 left rows.
# Processed 10730 left rows.
# Processed 10740 left rows.
# Processed 10750 left rows.
# Processed 10760 left rows.
# Processed 10770 left rows.
# Processed 10780 left rows.
# Processed 10790 left rows.
# Processed 10800 left rows.
# Processed 10810 left rows.
# Processed 10820 left rows.
# Processed 10830 left rows.
# Processed 10840 left rows.
# Processed 10850 left rows.
# Processed 10860 left rows.
# Processed 10870 left rows.
# Processed 10880 left rows.
# Processed 10890 left rows.
# Processed 10900 left rows.
# Processed 10910 left rows.
# Processed 10920 left rows.
# Processed 10930 left rows.
# Processed 10940 left rows.
# Processed 10950 left rows.
# Processed 10960 left rows.
# Processed 10970 left rows.
# Processed 10980 left rows.
# Processed 10990 left rows.
# Processed 11000 left rows.
# Processed 11010 left rows.
# Processed 11020 left rows.
# Processed 11030 left rows.
# Processed 11040 left rows.
# Processed 11050 left rows.
# Processed 11060 left rows.
# Processed 11070 left rows.
# Processed 11080 left rows.
# Processed 11090 left rows.
# Processed 11100 left rows.
# Processed 11110 left rows.
# Processed 11120 left rows.
# Processed 11130 left rows.
# Processed 11140 left rows.
# Processed 11150 left rows.
# Processed 11160 left rows.
# Processed 11170 left rows.
# Processed 11180 left rows.
# Processed 11190 left rows.
# Processed 11200 left rows.
# Processed 11210 left rows.
# Processed 11220 left rows.
# Processed 11230 left rows.
# Processed 11240 left rows.
# Processed 11250 left rows.
# Processed 11260 left rows.
# Processed 11270 left rows.
# Processed 11280 left rows.
# Processed 11290 left rows.
# Processed 11300 left rows.
# Processed 11310 left rows.
# Processed 11320 left rows.
# Processed 11330 left rows.
# Processed 11340 left rows.
# Processed 11350 left rows.
# Processed 11360 left rows.
# Processed 11370 left rows.
# Processed 11380 left rows.
# Processed 11390 left rows.
# Processed 11400 left rows.
# Processed 11410 left rows.
# Processed 11420 left rows.
# Processed 11430 left rows.
# Processed 11440 left rows.
# Processed 11450 left rows.
# Processed 11460 left rows.
# Processed 11470 left rows.
# Processed 11480 left rows.
# Processed 11490 left rows.
# Processed 11500 left rows.
# Processed 11510 left rows.
# Processed 11520 left rows.
# Processed 11530 left rows.
# Processed 11540 left rows.
# Processed 11550 left rows.
# Processed 11560 left rows.
# Processed 11570 left rows.
# Processed 11580 left rows.
# Processed 11590 left rows.
# Processed 11600 left rows.
# Processed 11610 left rows.
# Processed 11620 left rows.
# Processed 11630 left rows.
# Processed 11640 left rows.
# Processed 11650 left rows.
# Processed 11660 left rows.
# Processed 11670 left rows.
# Processed 11680 left rows.
# Processed 11690 left rows.
# Processed 11700 left rows.
# Processed 11710 left rows.
# Processed 11720 left rows.
# Processed 11730 left rows.
# Processed 11740 left rows.
# Processed 11750 left rows.
# Processed 11760 left rows.
# Processed 11770 left rows.
# Processed 11780 left rows.
# Processed 11790 left rows.
# Processed 11800 left rows.
# Processed 11810 left rows.
# Processed 11820 left rows.
# Processed 11830 left rows.
# Processed 11840 left rows.
# Processed 11850 left rows.
# Processed 11860 left rows.
# Processed 11870 left rows.
# Processed 11880 left rows.
# Processed 11890 left rows.
# Processed 11900 left rows.
# Processed 11910 left rows.
# Processed 11920 left rows.
# Processed 11930 left rows.
# Processed 11940 left rows.
# Processed 11950 left rows.
# Processed 11960 left rows.
# Processed 11970 left rows.
# Processed 11980 left rows.
# Processed 11990 left rows.
# Processed 12000 left rows.
# Processed 12010 left rows.
# Processed 12020 left rows.
# Processed 12030 left rows.
# Processed 12040 left rows.
# Processed 12050 left rows.
# Processed 12060 left rows.
# Processed 12070 left rows.
# Processed 12080 left rows.
# Processed 12090 left rows.
# Processed 12100 left rows.
# Processed 12110 left rows.
# Processed 12120 left rows.
# Processed 12130 left rows.
# Processed 12140 left rows.
# Processed 12150 left rows.
# Processed 12160 left rows.
# Processed 12170 left rows.
# Processed 12180 left rows.
# Processed 12190 left rows.
# Processed 12200 left rows.
# Processed 12210 left rows.
# Processed 12220 left rows.
# Processed 12230 left rows.
# Processed 12240 left rows.
# Processed 12250 left rows.
# Processed 12260 left rows.
# Processed 12270 left rows.
# Processed 12280 left rows.
# Processed 12290 left rows.
# Processed 12300 left rows.
# Processed 12310 left rows.
# Processed 12320 left rows.
# Processed 12330 left rows.
# Processed 12340 left rows.
# Processed 12350 left rows.
# Processed 12360 left rows.
# Processed 12370 left rows.
# Processed 12380 left rows.
# Processed 12390 left rows.
# Processed 12400 left rows.
# Processed 12410 left rows.
# Processed 12420 left rows.
# Processed 12430 left rows.
# Processed 12440 left rows.
# Processed 12450 left rows.
# Processed 12460 left rows.
# Processed 12470 left rows.
# Processed 12480 left rows.
# Processed 12490 left rows.
# Processed 12500 left rows.
# Processed 12510 left rows.
# Processed 12520 left rows.
# Processed 12530 left rows.
# Processed 12540 left rows.
# Processed 12550 left rows.
# Processed 12560 left rows.
# Processed 12570 left rows.
# Processed 12580 left rows.
# Processed 12590 left rows.
# Processed 12600 left rows.
# Processed 12610 left rows.
# Processed 12620 left rows.
# Processed 12630 left rows.
# Processed 12640 left rows.
# Processed 12650 left rows.
# Processed 12660 left rows.
# Processed 12670 left rows.
# Processed 12680 left rows.
# Processed 12690 left rows.
# Processed 12700 left rows.
# Processed 12710 left rows.
# Processed 12720 left rows.
# Processed 12730 left rows.
# Processed 12740 left rows.
# Processed 12750 left rows.
# Processed 12760 left rows.
# Processed 12770 left rows.
# Processed 12780 left rows.
# Processed 12790 left rows.
# Processed 12800 left rows.
# Processed 12810 left rows.
# Processed 12820 left rows.
# Processed 12830 left rows.
# Processed 12840 left rows.
# Processed 12850 left rows.
# Processed 12860 left rows.
# Processed 12870 left rows.
# Processed 12880 left rows.
# Processed 12890 left rows.
# Processed 12900 left rows.
# Processed 12910 left rows.
# Processed 12920 left rows.
# Processed 12930 left rows.
# Processed 12940 left rows.
# Processed 12950 left rows.
# Processed 12960 left rows.
# Processed 12970 left rows.
# Processed 12980 left rows.
# Processed 12990 left rows.
# Processed 13000 left rows.
# Processed 13010 left rows.
# Processed 13020 left rows.
# Processed 13030 left rows.
# Processed 13040 left rows.
# Processed 13050 left rows.
# Processed 13060 left rows.
# Processed 13070 left rows.
# Processed 13080 left rows.
# Processed 13090 left rows.
# Processed 13100 left rows.
# Processed 13110 left rows.
# Processed 13120 left rows.
# Processed 13130 left rows.
# Processed 13140 left rows.
# Processed 13150 left rows.
# Processed 13160 left rows.
# Processed 13170 left rows.
# Processed 13180 left rows.
# Processed 13190 left rows.
# Processed 13200 left rows.
# Processed 13210 left rows.
# Processed 13220 left rows.
# Processed 13230 left rows.
# Processed 13240 left rows.
# Processed 13250 left rows.
# Processed 13260 left rows.
# Processed 13270 left rows.
# Processed 13280 left rows.
# Processed 13290 left rows.
# Processed 13300 left rows.
# Processed 13310 left rows.
# Processed 13320 left rows.
# Processed 13330 left rows.
# Processed 13340 left rows.
# Processed 13350 left rows.
# Processed 13360 left rows.
# Processed 13370 left rows.
# Processed 13380 left rows.
# Processed 13390 left rows.
# Processed 13400 left rows.
# Processed 13410 left rows.
# Processed 13420 left rows.
# Processed 13430 left rows.
# Processed 13440 left rows.
# Processed 13450 left rows.
# Processed 13460 left rows.
# Processed 13470 left rows.
# Processed 13480 left rows.
# Processed 13490 left rows.
# Processed 13500 left rows.
# Processed 13510 left rows.
# Processed 13520 left rows.
# Processed 13530 left rows.
# Processed 13540 left rows.
# Processed 13550 left rows.
# Processed 13560 left rows.
# Processed 13570 left rows.
# Processed 13580 left rows.
# Processed 13590 left rows.
# Processed 13600 left rows.
# Processed 13610 left rows.
# Processed 13620 left rows.
# Processed 13630 left rows.
# Processed 13640 left rows.
# Processed 13650 left rows.
# Processed 13660 left rows.
# Processed 13670 left rows.
# Processed 13680 left rows.
# Processed 13690 left rows.
# Processed 13700 left rows.
# Processed 13710 left rows.
# Processed 13720 left rows.
# Processed 13730 left rows.
# Processed 13740 left rows.
# Processed 13750 left rows.
# Processed 13760 left rows.
# Processed 13770 left rows.
# Processed 13780 left rows.
# Processed 13790 left rows.
# Processed 13800 left rows.
# Processed 13810 left rows.
# Processed 13820 left rows.
# Processed 13830 left rows.
# Processed 13840 left rows.
# Processed 13850 left rows.
# Processed 13860 left rows.
# Processed 13870 left rows.
# Processed 13880 left rows.
# Processed 13890 left rows.
# Processed 13900 left rows.
# Processed 13910 left rows.
# Processed 13920 left rows.
# Processed 13930 left rows.
# Processed 13940 left rows.
# Processed 13950 left rows.
# Processed 13960 left rows.
# Processed 13970 left rows.
# Processed 13980 left rows.
# Processed 13990 left rows.
# Processed 14000 left rows.
# Processed 14010 left rows.
# Processed 14020 left rows.
# Processed 14030 left rows.
# Processed 14040 left rows.
# Processed 14050 left rows.
# Processed 14060 left rows.
# Processed 14070 left rows.
# Processed 14080 left rows.
# Processed 14090 left rows.
# Processed 14100 left rows.
# Processed 14110 left rows.
# Processed 14120 left rows.
# Processed 14130 left rows.
# Processed 14140 left rows.
# Processed 14150 left rows.
# Processed 14160 left rows.
# Processed 14170 left rows.
# Processed 14180 left rows.
# Processed 14190 left rows.
# Processed 14200 left rows.
# Processed 14210 left rows.
# Processed 14220 left rows.
# Processed 14230 left rows.
# Processed 14240 left rows.
# Processed 14250 left rows.
# Processed 14260 left rows.
# Processed 14270 left rows.
# Processed 14280 left rows.
# Processed 14290 left rows.
# Processed 14300 left rows.
# Processed 14310 left rows.
# Processed 14320 left rows.
# Processed 14330 left rows.
# Processed 14340 left rows.
# Processed 14350 left rows.
# Processed 14360 left rows.
# Processed 14370 left rows.
# Processed 14380 left rows.
# Processed 14390 left rows.
# Processed 14400 left rows.
# Processed 14410 left rows.
# Processed 14420 left rows.
# Processed 14430 left rows.
# Processed 14440 left rows.
# Processed 14450 left rows.
# Processed 14460 left rows.
# Processed 14470 left rows.
# Processed 14480 left rows.
# Processed 14490 left rows.
# Processed 14500 left rows.
# Processed 14510 left rows.
# Processed 14520 left rows.
# Processed 14530 left rows.
# Processed 14540 left rows.
# Processed 14550 left rows.
# Processed 14560 left rows.
# Processed 14570 left rows.
# Processed 14580 left rows.
# Processed 14590 left rows.
# Processed 14600 left rows.
# Processed 14610 left rows.
# Processed 14620 left rows.
# Processed 14630 left rows.
# Processed 14640 left rows.
# Processed 14650 left rows.
# Processed 14660 left rows.
# Processed 14670 left rows.
# Processed 14680 left rows.
# Processed 14690 left rows.
# Processed 14700 left rows.
# Processed 14710 left rows.
# Processed 14720 left rows.
# Processed 14730 left rows.
# Processed 14740 left rows.
# Processed 14750 left rows.
# Processed 14760 left rows.
# Processed 14770 left rows.
# Processed 14780 left rows.
# Processed 14790 left rows.
# Processed 14800 left rows.
# Processed 14810 left rows.
# Processed 14820 left rows.
# Processed 14830 left rows.
# Processed 14840 left rows.
# Processed 14850 left rows.
# Processed 14860 left rows.
# Processed 14870 left rows.
# Processed 14880 left rows.
# Processed 14890 left rows.
# Processed 14900 left rows.
# Processed 14910 left rows.
# Processed 14920 left rows.
# Processed 14930 left rows.
# Processed 14940 left rows.
# Processed 14950 left rows.
# Processed 14960 left rows.
# Processed 14970 left rows.
# Processed 14980 left rows.
# Processed 14990 left rows.
# Processed 15000 left rows.
# Processed 15010 left rows.
# Processed 15020 left rows.
# Processed 15030 left rows.
# Processed 15040 left rows.
# Processed 15050 left rows.
# Processed 15060 left rows.
# Processed 15070 left rows.
# Processed 15080 left rows.
# Processed 15090 left rows.
# Processed 15100 left rows.
# Processed 15110 left rows.
# Processed 15120 left rows.
# Processed 15130 left rows.
# Processed 15140 left rows.
# Processed 15150 left rows.
# Processed 15160 left rows.
# Processed 15170 left rows.
# Processed 15180 left rows.
# Processed 15190 left rows.
# Processed 15200 left rows.
# Processed 15210 left rows.
# Processed 15220 left rows.
# Processed 15230 left rows.
# Processed 15240 left rows.
# Processed 15250 left rows.
# Processed 15260 left rows.
# Processed 15270 left rows.
# Processed 15280 left rows.
# Processed 15290 left rows.
# Processed 15300 left rows.
# Processed 15310 left rows.
# Processed 15320 left rows.
# Processed 15330 left rows.
# Processed 15340 left rows.
# Processed 15350 left rows.
# Processed 15360 left rows.
# Processed 15370 left rows.
# Processed 15380 left rows.
# Processed 15390 left rows.
# Processed 15400 left rows.
# Processed 15410 left rows.
# Processed 15420 left rows.
# Processed 15430 left rows.
# Processed 15440 left rows.
# Processed 15450 left rows.
# Processed 15460 left rows.
# Processed 15470 left rows.
# Processed 15480 left rows.
# Processed 15490 left rows.
# Processed 15500 left rows.
# Processed 15510 left rows.
# Processed 15520 left rows.
# Processed 15530 left rows.
# Processed 15540 left rows.
# Processed 15550 left rows.
# Processed 15560 left rows.
# Processed 15570 left rows.
# Processed 15580 left rows.
# Processed 15590 left rows.
# Processed 15600 left rows.
# Processed 15610 left rows.
# Processed 15620 left rows.
# Processed 15630 left rows.
# Processed 15640 left rows.
# Processed 15650 left rows.
# Processed 15660 left rows.
# Processed 15670 left rows.
# Processed 15680 left rows.
# Processed 15690 left rows.
# Processed 15700 left rows.
# Processed 15710 left rows.
# Processed 15720 left rows.
# Processed 15730 left rows.
# Processed 15740 left rows.
# Processed 15750 left rows.
# Processed 15760 left rows.
# Processed 15770 left rows.
# Processed 15780 left rows.
# Processed 15790 left rows.
# Processed 15800 left rows.
# Processed 15810 left rows.
# Processed 15820 left rows.
# Processed 15830 left rows.
# Processed 15840 left rows.
# Processed 15850 left rows.
# Processed 15860 left rows.
# Processed 15870 left rows.
# Processed 15880 left rows.
# Processed 15890 left rows.
# Processed 15900 left rows.
# Processed 15910 left rows.
# Processed 15920 left rows.
# Processed 15930 left rows.
# Processed 15940 left rows.
# Processed 15950 left rows.
# Processed 15960 left rows.
# Processed 15970 left rows.
# Processed 15980 left rows.
# Processed 15990 left rows.
# Processed 16000 left rows.
# Processed 16010 left rows.
# Processed 16020 left rows.
# Processed 16030 left rows.
# Processed 16040 left rows.
# Processed 16050 left rows.
# Processed 16060 left rows.
# Processed 16070 left rows.
# Processed 16080 left rows.
# Processed 16090 left rows.
# Processed 16100 left rows.
# Processed 16110 left rows.
# Processed 16120 left rows.
# Processed 16130 left rows.
# Processed 16140 left rows.
# Processed 16150 left rows.
# Processed 16160 left rows.
# Processed 16170 left rows.
# Processed 16180 left rows.
# Processed 16190 left rows.
# Processed 16200 left rows.
# Processed 16210 left rows.
# Processed 16220 left rows.
# Processed 16230 left rows.
# Processed 16240 left rows.
# Processed 16250 left rows.
# Processed 16260 left rows.
# Processed 16270 left rows.
# Processed 16280 left rows.
# Processed 16290 left rows.
# Processed 16300 left rows.
# Processed 16310 left rows.
# Processed 16320 left rows.
# Processed 16330 left rows.
# Processed 16340 left rows.
# Processed 16350 left rows.
# Processed 16360 left rows.
# Processed 16370 left rows.
# Processed 16380 left rows.
# Processed 16390 left rows.
# Processed 16400 left rows.
# Processed 16410 left rows.
# Processed 16420 left rows.
# Processed 16430 left rows.
# Processed 16440 left rows.
# Processed 16450 left rows.
# Processed 16460 left rows.
# Processed 16470 left rows.
# Processed 16480 left rows.
# Processed 16490 left rows.
# Processed 16500 left rows.
# Processed 16510 left rows.
# Processed 16520 left rows.
# Processed 16530 left rows.
# Processed 16540 left rows.
# Processed 16550 left rows.
# Processed 16560 left rows.
# Processed 16570 left rows.
# Processed 16580 left rows.
# Processed 16590 left rows.
# Processed 16600 left rows.
# Processed 16610 left rows.
# Processed 16620 left rows.
# Processed 16630 left rows.
# Processed 16640 left rows.
# Processed 16650 left rows.
# Processed 16660 left rows.
# Processed 16670 left rows.
# Processed 16680 left rows.
# Processed 16690 left rows.
# Processed 16700 left rows.
# Processed 16710 left rows.
# Processed 16720 left rows.
# Processed 16730 left rows.
# Processed 16740 left rows.
# Processed 16750 left rows.
# Processed 16760 left rows.
# Processed 16770 left rows.
# Processed 16780 left rows.
# Processed 16790 left rows.
# Processed 16800 left rows.
# Processed 16810 left rows.
# Processed 16820 left rows.
# Processed 16830 left rows.
# Processed 16840 left rows.
# Processed 16850 left rows.
# Processed 16860 left rows.
# Processed 16870 left rows.
# Processed 16880 left rows.
# Processed 16890 left rows.
# Processed 16900 left rows.
# Processed 16910 left rows.
# Processed 16920 left rows.
# Processed 16930 left rows.
# Processed 16940 left rows.
# Processed 16950 left rows.
# Processed 16960 left rows.
# Processed 16970 left rows.
# Processed 16980 left rows.
# Processed 16990 left rows.
# Processed 17000 left rows.
# Processed 17010 left rows.
# Processed 17020 left rows.
# Processed 17030 left rows.
# Processed 17040 left rows.
# Processed 17050 left rows.
# Processed 17060 left rows.
# Processed 17070 left rows.
# Processed 17080 left rows.
# Processed 17090 left rows.
# Processed 17100 left rows.
# Processed 17110 left rows.
# Processed 17120 left rows.
# Processed 17130 left rows.
# Processed 17140 left rows.
# Processed 17150 left rows.
# Processed 17160 left rows.
# Processed 17170 left rows.
# Processed 17180 left rows.
# Processed 17190 left rows.
# Processed 17200 left rows.
# Processed 17210 left rows.
# Processed 17220 left rows.
# Processed 17230 left rows.
# Processed 17240 left rows.
# Processed 17250 left rows.
# Processed 17260 left rows.
# Processed 17270 left rows.
# Processed 17280 left rows.
# Processed 17290 left rows.
# Processed 17300 left rows.
# Processed 17310 left rows.
# Processed 17320 left rows.
# Processed 17330 left rows.
# Processed 17340 left rows.
# Processed 17350 left rows.
# Processed 17360 left rows.
# Processed 17370 left rows.
# Processed 17380 left rows.
# Processed 17390 left rows.
# Processed 17400 left rows.
# Processed 17410 left rows.
# Processed 17420 left rows.
# Processed 17430 left rows.
# Processed 17440 left rows.
# Processed 17450 left rows.
# Processed 17460 left rows.
# Processed 17470 left rows.
# Processed 17480 left rows.
# Processed 17490 left rows.
# Processed 17500 left rows.
# Processed 17510 left rows.
# Processed 17520 left rows.
# Processed 17530 left rows.
# Processed 17540 left rows.
# Processed 17550 left rows.
# Processed 17560 left rows.
# Processed 17570 left rows.
# Processed 17580 left rows.
# Processed 17590 left rows.
# Processed 17600 left rows.
# Processed 17610 left rows.
# Processed 17620 left rows.
# Processed 17630 left rows.
# Processed 17640 left rows.
# Processed 17650 left rows.
# Processed 17660 left rows.
# Processed 17670 left rows.
# Processed 17680 left rows.
# Processed 17690 left rows.
# Processed 17700 left rows.
# Processed 17710 left rows.
# Processed 17720 left rows.
# Processed 17730 left rows.
# Processed 17740 left rows.
# Processed 17750 left rows.
# Processed 17760 left rows.
# Processed 17770 left rows.
# Processed 17780 left rows.
# Processed 17790 left rows.
# Processed 17800 left rows.
# Processed 17810 left rows.
# Processed 17820 left rows.
# Processed 17830 left rows.
# Processed 17840 left rows.
# Processed 17850 left rows.
# Processed 17860 left rows.
# Processed 17870 left rows.
# Processed 17880 left rows.
# Processed 17890 left rows.
# Processed 17900 left rows.
# Processed 17910 left rows.
# Processed 17920 left rows.
# Processed 17930 left rows.
# Processed 17940 left rows.
# Processed 17950 left rows.
# Processed 17960 left rows.
# Processed 17970 left rows.
# Processed 17980 left rows.
# Processed 17990 left rows.
# Processed 18000 left rows.
# Processed 18010 left rows.
# Processed 18020 left rows.
# Processed 18030 left rows.
# Processed 18040 left rows.
# Processed 18050 left rows.
# Processed 18060 left rows.
# Processed 18070 left rows.
# Processed 18080 left rows.
# Processed 18090 left rows.
# Processed 18100 left rows.
# Processed 18110 left rows.
# Processed 18120 left rows.
# Processed 18130 left rows.
# Processed 18140 left rows.
# Processed 18150 left rows.
# Processed 18160 left rows.
# Processed 18170 left rows.
# Processed 18180 left rows.
# Processed 18190 left rows.
# Processed 18200 left rows.
# Processed 18210 left rows.
# Processed 18220 left rows.
# Processed 18230 left rows.
# Processed 18240 left rows.
# Processed 18250 left rows.
# Processed 18260 left rows.
# Processed 18270 left rows.
# Processed 18280 left rows.
# Processed 18290 left rows.
# Processed 18300 left rows.
# Processed 18310 left rows.
# Processed 18320 left rows.
# Processed 18330 left rows.
# Processed 18340 left rows.
# Processed 18350 left rows.
# Processed 18360 left rows.
# Processed 18370 left rows.
# Processed 18380 left rows.
# Processed 18390 left rows.
# Processed 18400 left rows.
# Processed 18410 left rows.
# Processed 18420 left rows.
# Processed 18430 left rows.
# Processed 18440 left rows.
# Processed 18450 left rows.
# Processed 18460 left rows.
# Processed 18470 left rows.
# Processed 18480 left rows.
# Processed 18490 left rows.
# Processed 18500 left rows.
# Processed 18510 left rows.
# Processed 18520 left rows.
# Processed 18530 left rows.
# Processed 18540 left rows.
# Processed 18550 left rows.
# Processed 18560 left rows.
# Processed 18570 left rows.
# Processed 18580 left rows.
# Processed 18590 left rows.
# Processed 18600 left rows.
# Processed 18610 left rows.
# Processed 18620 left rows.
# Processed 18630 left rows.
# Processed 18640 left rows.
# Processed 18650 left rows.
# Processed 18660 left rows.
# Processed 18670 left rows.
# Processed 18680 left rows.
# Processed 18690 left rows.
# Processed 18700 left rows.
# Processed 18710 left rows.
# Processed 18720 left rows.
# Processed 18730 left rows.
# Processed 18740 left rows.
# Processed 18750 left rows.
# Processed 18760 left rows.
# Processed 18770 left rows.
# Processed 18780 left rows.
# Processed 18790 left rows.
# Processed 18800 left rows.
# Processed 18810 left rows.
# Processed 18820 left rows.
# Processed 18830 left rows.
# Processed 18840 left rows.
# Processed 18850 left rows.
# Processed 18860 left rows.
# Processed 18870 left rows.
# Processed 18880 left rows.
# Processed 18890 left rows.
# Processed 18900 left rows.
# Processed 18910 left rows.
# Processed 18920 left rows.
# Processed 18930 left rows.
# Processed 18940 left rows.
# Processed 18950 left rows.
# Processed 18960 left rows.
# Processed 18970 left rows.
# Processed 18980 left rows.
# Processed 18990 left rows.
# Processed 19000 left rows.
# Processed 19010 left rows.
# Processed 19020 left rows.
# Processed 19030 left rows.
# Processed 19040 left rows.
# Processed 19050 left rows.
# Processed 19060 left rows.
# Processed 19070 left rows.
# Processed 19080 left rows.
# Processed 19090 left rows.
# Processed 19100 left rows.
# Processed 19110 left rows.
# Processed 19120 left rows.
# Processed 19130 left rows.
# Processed 19140 left rows.
# Processed 19150 left rows.
# Processed 19160 left rows.
# Processed 19170 left rows.
# Processed 19180 left rows.
# Processed 19190 left rows.
# Processed 19200 left rows.
# Processed 19210 left rows.
# Processed 19220 left rows.
# Processed 19230 left rows.
# Processed 19240 left rows.
# Processed 19250 left rows.
# Processed 19260 left rows.
# Processed 19270 left rows.
# Processed 19280 left rows.
# Processed 19290 left rows.
# Processed 19300 left rows.
# Processed 19310 left rows.
# Processed 19320 left rows.
# Processed 19330 left rows.
# Processed 19340 left rows.
# Processed 19350 left rows.
# Processed 19360 left rows.
# Processed 19370 left rows.
# +------------+----------+----------+-------------+------------+---------+
# | playerID   |   yearID | teamID   | nameFirst   | nameLast   |   G_all |
# +============+==========+==========+=============+============+=========+
# | baxtemi01  |     2010 | SDN      | Mike        | Baxter     |       9 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2011 | NYN      | Mike        | Baxter     |      22 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2012 | NYN      | Mike        | Baxter     |      89 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2013 | NYN      | Mike        | Baxter     |      74 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2014 | LAN      | Mike        | Baxter     |       4 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2015 | CHN      | Mike        | Baxter     |      34 |
# +------------+----------+----------+-------------+------------+---------+

# %%
tab.get_access_path_test()
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'batting'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'batting'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'batting' group by index_name, table_name, type, column_name, index_order order by index_order
# primary_index
# 18915

# %%
tab.sub_where_template_test()
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'people'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'people'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'people' group by index_name, table_name, type, column_name, index_order order by index_order
# {'nameFirst': 'Hank', 'nameLast': 'Aaron'}

# %%
tab.test_find_by_template_index()
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'people'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'people'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'people' group by index_name, table_name, type, column_name, index_order order by index_order
# [
#   {
#     "bats": "R",
#     "bbrefID": "aaronha01",
#     "birthCity": "Mobile",
#     "birthCountry": "USA",
#     "birthDay": "5",
#     "birthMonth": "2",
#     "birthState": "AL",
#     "birthYear": "1934",
#     "deathCity": "",
#     "deathCountry": "",
#     "deathDay": "",
#     "deathMonth": "",
#     "deathState": "",
#     "deathYear": "",
#     "debut": "1954-04-13",
#     "finalGame": "1976-10-03",
#     "height": "72",
#     "nameFirst": "Hank",
#     "nameGiven": "Henry Louis",
#     "nameLast": "Aaron",
#     "playerID": "aaronha01",
#     "retroID": "aaroh101",
#     "throws": "R",
#     "weight": "180"
#   }
# ]

# %%
tab.smart_join_test()
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'people'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'people'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'people' group by index_name, table_name, type, column_name, index_order order by index_order
# Running load core definition
# Q =  select * from csvtables where table_name = 'appearances'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'appearances'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'appearances' group by index_name, table_name, type, column_name, index_order order by index_order
# +------------+----------+----------+-------------+------------+---------+
# | playerID   |   yearID | teamID   | nameFirst   | nameLast   |   G_all |
# +============+==========+==========+=============+============+=========+
# | baxtemi01  |     2010 | SDN      | Mike        | Baxter     |       9 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2011 | NYN      | Mike        | Baxter     |      22 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2012 | NYN      | Mike        | Baxter     |      89 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2013 | NYN      | Mike        | Baxter     |      74 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2014 | LAN      | Mike        | Baxter     |       4 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2015 | CHN      | Mike        | Baxter     |      34 |
# +------------+----------+----------+-------------+------------+---------+

# %%
# Compare the time it takes to do the dumb join and the smart join below
# %time #This is a timer that will track how long it takes to execute your cell. 

# Times will vary based on how long it takes to query your AWS Server, but you should see a notable improvement using smart_join()

#----Your Code Here----
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 13.8 µs

# %%
# %%time
tab.dumb_join_test()
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'people'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'people'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'people' group by index_name, table_name, type, column_name, index_order order by index_order
# Running load core definition
# Q =  select * from csvtables where table_name = 'appearances'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'appearances'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'appearances' group by index_name, table_name, type, column_name, index_order order by index_order
# Processed 10 left rows.
# Processed 20 left rows.
# Processed 30 left rows.
# Processed 40 left rows.
# Processed 50 left rows.
# Processed 60 left rows.
# Processed 70 left rows.
# Processed 80 left rows.
# Processed 90 left rows.
# Processed 100 left rows.
# Processed 110 left rows.
# Processed 120 left rows.
# Processed 130 left rows.
# Processed 140 left rows.
# Processed 150 left rows.
# Processed 160 left rows.
# Processed 170 left rows.
# Processed 180 left rows.
# Processed 190 left rows.
# Processed 200 left rows.
# Processed 210 left rows.
# Processed 220 left rows.
# Processed 230 left rows.
# Processed 240 left rows.
# Processed 250 left rows.
# Processed 260 left rows.
# Processed 270 left rows.
# Processed 280 left rows.
# Processed 290 left rows.
# Processed 300 left rows.
# Processed 310 left rows.
# Processed 320 left rows.
# Processed 330 left rows.
# Processed 340 left rows.
# Processed 350 left rows.
# Processed 360 left rows.
# Processed 370 left rows.
# Processed 380 left rows.
# Processed 390 left rows.
# Processed 400 left rows.
# Processed 410 left rows.
# Processed 420 left rows.
# Processed 430 left rows.
# Processed 440 left rows.
# Processed 450 left rows.
# Processed 460 left rows.
# Processed 470 left rows.
# Processed 480 left rows.
# Processed 490 left rows.
# Processed 500 left rows.
# Processed 510 left rows.
# Processed 520 left rows.
# Processed 530 left rows.
# Processed 540 left rows.
# Processed 550 left rows.
# Processed 560 left rows.
# Processed 570 left rows.
# Processed 580 left rows.
# Processed 590 left rows.
# Processed 600 left rows.
# Processed 610 left rows.
# Processed 620 left rows.
# Processed 630 left rows.
# Processed 640 left rows.
# Processed 650 left rows.
# Processed 660 left rows.
# Processed 670 left rows.
# Processed 680 left rows.
# Processed 690 left rows.
# Processed 700 left rows.
# Processed 710 left rows.
# Processed 720 left rows.
# Processed 730 left rows.
# Processed 740 left rows.
# Processed 750 left rows.
# Processed 760 left rows.
# Processed 770 left rows.
# Processed 780 left rows.
# Processed 790 left rows.
# Processed 800 left rows.
# Processed 810 left rows.
# Processed 820 left rows.
# Processed 830 left rows.
# Processed 840 left rows.
# Processed 850 left rows.
# Processed 860 left rows.
# Processed 870 left rows.
# Processed 880 left rows.
# Processed 890 left rows.
# Processed 900 left rows.
# Processed 910 left rows.
# Processed 920 left rows.
# Processed 930 left rows.
# Processed 940 left rows.
# Processed 950 left rows.
# Processed 960 left rows.
# Processed 970 left rows.
# Processed 980 left rows.
# Processed 990 left rows.
# Processed 1000 left rows.
# Processed 1010 left rows.
# Processed 1020 left rows.
# Processed 1030 left rows.
# Processed 1040 left rows.
# Processed 1050 left rows.
# Processed 1060 left rows.
# Processed 1070 left rows.
# Processed 1080 left rows.
# Processed 1090 left rows.
# Processed 1100 left rows.
# Processed 1110 left rows.
# Processed 1120 left rows.
# Processed 1130 left rows.
# Processed 1140 left rows.
# Processed 1150 left rows.
# Processed 1160 left rows.
# Processed 1170 left rows.
# Processed 1180 left rows.
# Processed 1190 left rows.
# Processed 1200 left rows.
# Processed 1210 left rows.
# Processed 1220 left rows.
# Processed 1230 left rows.
# Processed 1240 left rows.
# Processed 1250 left rows.
# Processed 1260 left rows.
# Processed 1270 left rows.
# Processed 1280 left rows.
# Processed 1290 left rows.
# Processed 1300 left rows.
# Processed 1310 left rows.
# Processed 1320 left rows.
# Processed 1330 left rows.
# Processed 1340 left rows.
# Processed 1350 left rows.
# Processed 1360 left rows.
# Processed 1370 left rows.
# Processed 1380 left rows.
# Processed 1390 left rows.
# Processed 1400 left rows.
# Processed 1410 left rows.
# Processed 1420 left rows.
# Processed 1430 left rows.
# Processed 1440 left rows.
# Processed 1450 left rows.
# Processed 1460 left rows.
# Processed 1470 left rows.
# Processed 1480 left rows.
# Processed 1490 left rows.
# Processed 1500 left rows.
# Processed 1510 left rows.
# Processed 1520 left rows.
# Processed 1530 left rows.
# Processed 1540 left rows.
# Processed 1550 left rows.
# Processed 1560 left rows.
# Processed 1570 left rows.
# Processed 1580 left rows.
# Processed 1590 left rows.
# Processed 1600 left rows.
# Processed 1610 left rows.
# Processed 1620 left rows.
# Processed 1630 left rows.
# Processed 1640 left rows.
# Processed 1650 left rows.
# Processed 1660 left rows.
# Processed 1670 left rows.
# Processed 1680 left rows.
# Processed 1690 left rows.
# Processed 1700 left rows.
# Processed 1710 left rows.
# Processed 1720 left rows.
# Processed 1730 left rows.
# Processed 1740 left rows.
# Processed 1750 left rows.
# Processed 1760 left rows.
# Processed 1770 left rows.
# Processed 1780 left rows.
# Processed 1790 left rows.
# Processed 1800 left rows.
# Processed 1810 left rows.
# Processed 1820 left rows.
# Processed 1830 left rows.
# Processed 1840 left rows.
# Processed 1850 left rows.
# Processed 1860 left rows.
# Processed 1870 left rows.
# Processed 1880 left rows.
# Processed 1890 left rows.
# Processed 1900 left rows.
# Processed 1910 left rows.
# Processed 1920 left rows.
# Processed 1930 left rows.
# Processed 1940 left rows.
# Processed 1950 left rows.
# Processed 1960 left rows.
# Processed 1970 left rows.
# Processed 1980 left rows.
# Processed 1990 left rows.
# Processed 2000 left rows.
# Processed 2010 left rows.
# Processed 2020 left rows.
# Processed 2030 left rows.
# Processed 2040 left rows.
# Processed 2050 left rows.
# Processed 2060 left rows.
# Processed 2070 left rows.
# Processed 2080 left rows.
# Processed 2090 left rows.
# Processed 2100 left rows.
# Processed 2110 left rows.
# Processed 2120 left rows.
# Processed 2130 left rows.
# Processed 2140 left rows.
# Processed 2150 left rows.
# Processed 2160 left rows.
# Processed 2170 left rows.
# Processed 2180 left rows.
# Processed 2190 left rows.
# Processed 2200 left rows.
# Processed 2210 left rows.
# Processed 2220 left rows.
# Processed 2230 left rows.
# Processed 2240 left rows.
# Processed 2250 left rows.
# Processed 2260 left rows.
# Processed 2270 left rows.
# Processed 2280 left rows.
# Processed 2290 left rows.
# Processed 2300 left rows.
# Processed 2310 left rows.
# Processed 2320 left rows.
# Processed 2330 left rows.
# Processed 2340 left rows.
# Processed 2350 left rows.
# Processed 2360 left rows.
# Processed 2370 left rows.
# Processed 2380 left rows.
# Processed 2390 left rows.
# Processed 2400 left rows.
# Processed 2410 left rows.
# Processed 2420 left rows.
# Processed 2430 left rows.
# Processed 2440 left rows.
# Processed 2450 left rows.
# Processed 2460 left rows.
# Processed 2470 left rows.
# Processed 2480 left rows.
# Processed 2490 left rows.
# Processed 2500 left rows.
# Processed 2510 left rows.
# Processed 2520 left rows.
# Processed 2530 left rows.
# Processed 2540 left rows.
# Processed 2550 left rows.
# Processed 2560 left rows.
# Processed 2570 left rows.
# Processed 2580 left rows.
# Processed 2590 left rows.
# Processed 2600 left rows.
# Processed 2610 left rows.
# Processed 2620 left rows.
# Processed 2630 left rows.
# Processed 2640 left rows.
# Processed 2650 left rows.
# Processed 2660 left rows.
# Processed 2670 left rows.
# Processed 2680 left rows.
# Processed 2690 left rows.
# Processed 2700 left rows.
# Processed 2710 left rows.
# Processed 2720 left rows.
# Processed 2730 left rows.
# Processed 2740 left rows.
# Processed 2750 left rows.
# Processed 2760 left rows.
# Processed 2770 left rows.
# Processed 2780 left rows.
# Processed 2790 left rows.
# Processed 2800 left rows.
# Processed 2810 left rows.
# Processed 2820 left rows.
# Processed 2830 left rows.
# Processed 2840 left rows.
# Processed 2850 left rows.
# Processed 2860 left rows.
# Processed 2870 left rows.
# Processed 2880 left rows.
# Processed 2890 left rows.
# Processed 2900 left rows.
# Processed 2910 left rows.
# Processed 2920 left rows.
# Processed 2930 left rows.
# Processed 2940 left rows.
# Processed 2950 left rows.
# Processed 2960 left rows.
# Processed 2970 left rows.
# Processed 2980 left rows.
# Processed 2990 left rows.
# Processed 3000 left rows.
# Processed 3010 left rows.
# Processed 3020 left rows.
# Processed 3030 left rows.
# Processed 3040 left rows.
# Processed 3050 left rows.
# Processed 3060 left rows.
# Processed 3070 left rows.
# Processed 3080 left rows.
# Processed 3090 left rows.
# Processed 3100 left rows.
# Processed 3110 left rows.
# Processed 3120 left rows.
# Processed 3130 left rows.
# Processed 3140 left rows.
# Processed 3150 left rows.
# Processed 3160 left rows.
# Processed 3170 left rows.
# Processed 3180 left rows.
# Processed 3190 left rows.
# Processed 3200 left rows.
# Processed 3210 left rows.
# Processed 3220 left rows.
# Processed 3230 left rows.
# Processed 3240 left rows.
# Processed 3250 left rows.
# Processed 3260 left rows.
# Processed 3270 left rows.
# Processed 3280 left rows.
# Processed 3290 left rows.
# Processed 3300 left rows.
# Processed 3310 left rows.
# Processed 3320 left rows.
# Processed 3330 left rows.
# Processed 3340 left rows.
# Processed 3350 left rows.
# Processed 3360 left rows.
# Processed 3370 left rows.
# Processed 3380 left rows.
# Processed 3390 left rows.
# Processed 3400 left rows.
# Processed 3410 left rows.
# Processed 3420 left rows.
# Processed 3430 left rows.
# Processed 3440 left rows.
# Processed 3450 left rows.
# Processed 3460 left rows.
# Processed 3470 left rows.
# Processed 3480 left rows.
# Processed 3490 left rows.
# Processed 3500 left rows.
# Processed 3510 left rows.
# Processed 3520 left rows.
# Processed 3530 left rows.
# Processed 3540 left rows.
# Processed 3550 left rows.
# Processed 3560 left rows.
# Processed 3570 left rows.
# Processed 3580 left rows.
# Processed 3590 left rows.
# Processed 3600 left rows.
# Processed 3610 left rows.
# Processed 3620 left rows.
# Processed 3630 left rows.
# Processed 3640 left rows.
# Processed 3650 left rows.
# Processed 3660 left rows.
# Processed 3670 left rows.
# Processed 3680 left rows.
# Processed 3690 left rows.
# Processed 3700 left rows.
# Processed 3710 left rows.
# Processed 3720 left rows.
# Processed 3730 left rows.
# Processed 3740 left rows.
# Processed 3750 left rows.
# Processed 3760 left rows.
# Processed 3770 left rows.
# Processed 3780 left rows.
# Processed 3790 left rows.
# Processed 3800 left rows.
# Processed 3810 left rows.
# Processed 3820 left rows.
# Processed 3830 left rows.
# Processed 3840 left rows.
# Processed 3850 left rows.
# Processed 3860 left rows.
# Processed 3870 left rows.
# Processed 3880 left rows.
# Processed 3890 left rows.
# Processed 3900 left rows.
# Processed 3910 left rows.
# Processed 3920 left rows.
# Processed 3930 left rows.
# Processed 3940 left rows.
# Processed 3950 left rows.
# Processed 3960 left rows.
# Processed 3970 left rows.
# Processed 3980 left rows.
# Processed 3990 left rows.
# Processed 4000 left rows.
# Processed 4010 left rows.
# Processed 4020 left rows.
# Processed 4030 left rows.
# Processed 4040 left rows.
# Processed 4050 left rows.
# Processed 4060 left rows.
# Processed 4070 left rows.
# Processed 4080 left rows.
# Processed 4090 left rows.
# Processed 4100 left rows.
# Processed 4110 left rows.
# Processed 4120 left rows.
# Processed 4130 left rows.
# Processed 4140 left rows.
# Processed 4150 left rows.
# Processed 4160 left rows.
# Processed 4170 left rows.
# Processed 4180 left rows.
# Processed 4190 left rows.
# Processed 4200 left rows.
# Processed 4210 left rows.
# Processed 4220 left rows.
# Processed 4230 left rows.
# Processed 4240 left rows.
# Processed 4250 left rows.
# Processed 4260 left rows.
# Processed 4270 left rows.
# Processed 4280 left rows.
# Processed 4290 left rows.
# Processed 4300 left rows.
# Processed 4310 left rows.
# Processed 4320 left rows.
# Processed 4330 left rows.
# Processed 4340 left rows.
# Processed 4350 left rows.
# Processed 4360 left rows.
# Processed 4370 left rows.
# Processed 4380 left rows.
# Processed 4390 left rows.
# Processed 4400 left rows.
# Processed 4410 left rows.
# Processed 4420 left rows.
# Processed 4430 left rows.
# Processed 4440 left rows.
# Processed 4450 left rows.
# Processed 4460 left rows.
# Processed 4470 left rows.
# Processed 4480 left rows.
# Processed 4490 left rows.
# Processed 4500 left rows.
# Processed 4510 left rows.
# Processed 4520 left rows.
# Processed 4530 left rows.
# Processed 4540 left rows.
# Processed 4550 left rows.
# Processed 4560 left rows.
# Processed 4570 left rows.
# Processed 4580 left rows.
# Processed 4590 left rows.
# Processed 4600 left rows.
# Processed 4610 left rows.
# Processed 4620 left rows.
# Processed 4630 left rows.
# Processed 4640 left rows.
# Processed 4650 left rows.
# Processed 4660 left rows.
# Processed 4670 left rows.
# Processed 4680 left rows.
# Processed 4690 left rows.
# Processed 4700 left rows.
# Processed 4710 left rows.
# Processed 4720 left rows.
# Processed 4730 left rows.
# Processed 4740 left rows.
# Processed 4750 left rows.
# Processed 4760 left rows.
# Processed 4770 left rows.
# Processed 4780 left rows.
# Processed 4790 left rows.
# Processed 4800 left rows.
# Processed 4810 left rows.
# Processed 4820 left rows.
# Processed 4830 left rows.
# Processed 4840 left rows.
# Processed 4850 left rows.
# Processed 4860 left rows.
# Processed 4870 left rows.
# Processed 4880 left rows.
# Processed 4890 left rows.
# Processed 4900 left rows.
# Processed 4910 left rows.
# Processed 4920 left rows.
# Processed 4930 left rows.
# Processed 4940 left rows.
# Processed 4950 left rows.
# Processed 4960 left rows.
# Processed 4970 left rows.
# Processed 4980 left rows.
# Processed 4990 left rows.
# Processed 5000 left rows.
# Processed 5010 left rows.
# Processed 5020 left rows.
# Processed 5030 left rows.
# Processed 5040 left rows.
# Processed 5050 left rows.
# Processed 5060 left rows.
# Processed 5070 left rows.
# Processed 5080 left rows.
# Processed 5090 left rows.
# Processed 5100 left rows.
# Processed 5110 left rows.
# Processed 5120 left rows.
# Processed 5130 left rows.
# Processed 5140 left rows.
# Processed 5150 left rows.
# Processed 5160 left rows.
# Processed 5170 left rows.
# Processed 5180 left rows.
# Processed 5190 left rows.
# Processed 5200 left rows.
# Processed 5210 left rows.
# Processed 5220 left rows.
# Processed 5230 left rows.
# Processed 5240 left rows.
# Processed 5250 left rows.
# Processed 5260 left rows.
# Processed 5270 left rows.
# Processed 5280 left rows.
# Processed 5290 left rows.
# Processed 5300 left rows.
# Processed 5310 left rows.
# Processed 5320 left rows.
# Processed 5330 left rows.
# Processed 5340 left rows.
# Processed 5350 left rows.
# Processed 5360 left rows.
# Processed 5370 left rows.
# Processed 5380 left rows.
# Processed 5390 left rows.
# Processed 5400 left rows.
# Processed 5410 left rows.
# Processed 5420 left rows.
# Processed 5430 left rows.
# Processed 5440 left rows.
# Processed 5450 left rows.
# Processed 5460 left rows.
# Processed 5470 left rows.
# Processed 5480 left rows.
# Processed 5490 left rows.
# Processed 5500 left rows.
# Processed 5510 left rows.
# Processed 5520 left rows.
# Processed 5530 left rows.
# Processed 5540 left rows.
# Processed 5550 left rows.
# Processed 5560 left rows.
# Processed 5570 left rows.
# Processed 5580 left rows.
# Processed 5590 left rows.
# Processed 5600 left rows.
# Processed 5610 left rows.
# Processed 5620 left rows.
# Processed 5630 left rows.
# Processed 5640 left rows.
# Processed 5650 left rows.
# Processed 5660 left rows.
# Processed 5670 left rows.
# Processed 5680 left rows.
# Processed 5690 left rows.
# Processed 5700 left rows.
# Processed 5710 left rows.
# Processed 5720 left rows.
# Processed 5730 left rows.
# Processed 5740 left rows.
# Processed 5750 left rows.
# Processed 5760 left rows.
# Processed 5770 left rows.
# Processed 5780 left rows.
# Processed 5790 left rows.
# Processed 5800 left rows.
# Processed 5810 left rows.
# Processed 5820 left rows.
# Processed 5830 left rows.
# Processed 5840 left rows.
# Processed 5850 left rows.
# Processed 5860 left rows.
# Processed 5870 left rows.
# Processed 5880 left rows.
# Processed 5890 left rows.
# Processed 5900 left rows.
# Processed 5910 left rows.
# Processed 5920 left rows.
# Processed 5930 left rows.
# Processed 5940 left rows.
# Processed 5950 left rows.
# Processed 5960 left rows.
# Processed 5970 left rows.
# Processed 5980 left rows.
# Processed 5990 left rows.
# Processed 6000 left rows.
# Processed 6010 left rows.
# Processed 6020 left rows.
# Processed 6030 left rows.
# Processed 6040 left rows.
# Processed 6050 left rows.
# Processed 6060 left rows.
# Processed 6070 left rows.
# Processed 6080 left rows.
# Processed 6090 left rows.
# Processed 6100 left rows.
# Processed 6110 left rows.
# Processed 6120 left rows.
# Processed 6130 left rows.
# Processed 6140 left rows.
# Processed 6150 left rows.
# Processed 6160 left rows.
# Processed 6170 left rows.
# Processed 6180 left rows.
# Processed 6190 left rows.
# Processed 6200 left rows.
# Processed 6210 left rows.
# Processed 6220 left rows.
# Processed 6230 left rows.
# Processed 6240 left rows.
# Processed 6250 left rows.
# Processed 6260 left rows.
# Processed 6270 left rows.
# Processed 6280 left rows.
# Processed 6290 left rows.
# Processed 6300 left rows.
# Processed 6310 left rows.
# Processed 6320 left rows.
# Processed 6330 left rows.
# Processed 6340 left rows.
# Processed 6350 left rows.
# Processed 6360 left rows.
# Processed 6370 left rows.
# Processed 6380 left rows.
# Processed 6390 left rows.
# Processed 6400 left rows.
# Processed 6410 left rows.
# Processed 6420 left rows.
# Processed 6430 left rows.
# Processed 6440 left rows.
# Processed 6450 left rows.
# Processed 6460 left rows.
# Processed 6470 left rows.
# Processed 6480 left rows.
# Processed 6490 left rows.
# Processed 6500 left rows.
# Processed 6510 left rows.
# Processed 6520 left rows.
# Processed 6530 left rows.
# Processed 6540 left rows.
# Processed 6550 left rows.
# Processed 6560 left rows.
# Processed 6570 left rows.
# Processed 6580 left rows.
# Processed 6590 left rows.
# Processed 6600 left rows.
# Processed 6610 left rows.
# Processed 6620 left rows.
# Processed 6630 left rows.
# Processed 6640 left rows.
# Processed 6650 left rows.
# Processed 6660 left rows.
# Processed 6670 left rows.
# Processed 6680 left rows.
# Processed 6690 left rows.
# Processed 6700 left rows.
# Processed 6710 left rows.
# Processed 6720 left rows.
# Processed 6730 left rows.
# Processed 6740 left rows.
# Processed 6750 left rows.
# Processed 6760 left rows.
# Processed 6770 left rows.
# Processed 6780 left rows.
# Processed 6790 left rows.
# Processed 6800 left rows.
# Processed 6810 left rows.
# Processed 6820 left rows.
# Processed 6830 left rows.
# Processed 6840 left rows.
# Processed 6850 left rows.
# Processed 6860 left rows.
# Processed 6870 left rows.
# Processed 6880 left rows.
# Processed 6890 left rows.
# Processed 6900 left rows.
# Processed 6910 left rows.
# Processed 6920 left rows.
# Processed 6930 left rows.
# Processed 6940 left rows.
# Processed 6950 left rows.
# Processed 6960 left rows.
# Processed 6970 left rows.
# Processed 6980 left rows.
# Processed 6990 left rows.
# Processed 7000 left rows.
# Processed 7010 left rows.
# Processed 7020 left rows.
# Processed 7030 left rows.
# Processed 7040 left rows.
# Processed 7050 left rows.
# Processed 7060 left rows.
# Processed 7070 left rows.
# Processed 7080 left rows.
# Processed 7090 left rows.
# Processed 7100 left rows.
# Processed 7110 left rows.
# Processed 7120 left rows.
# Processed 7130 left rows.
# Processed 7140 left rows.
# Processed 7150 left rows.
# Processed 7160 left rows.
# Processed 7170 left rows.
# Processed 7180 left rows.
# Processed 7190 left rows.
# Processed 7200 left rows.
# Processed 7210 left rows.
# Processed 7220 left rows.
# Processed 7230 left rows.
# Processed 7240 left rows.
# Processed 7250 left rows.
# Processed 7260 left rows.
# Processed 7270 left rows.
# Processed 7280 left rows.
# Processed 7290 left rows.
# Processed 7300 left rows.
# Processed 7310 left rows.
# Processed 7320 left rows.
# Processed 7330 left rows.
# Processed 7340 left rows.
# Processed 7350 left rows.
# Processed 7360 left rows.
# Processed 7370 left rows.
# Processed 7380 left rows.
# Processed 7390 left rows.
# Processed 7400 left rows.
# Processed 7410 left rows.
# Processed 7420 left rows.
# Processed 7430 left rows.
# Processed 7440 left rows.
# Processed 7450 left rows.
# Processed 7460 left rows.
# Processed 7470 left rows.
# Processed 7480 left rows.
# Processed 7490 left rows.
# Processed 7500 left rows.
# Processed 7510 left rows.
# Processed 7520 left rows.
# Processed 7530 left rows.
# Processed 7540 left rows.
# Processed 7550 left rows.
# Processed 7560 left rows.
# Processed 7570 left rows.
# Processed 7580 left rows.
# Processed 7590 left rows.
# Processed 7600 left rows.
# Processed 7610 left rows.
# Processed 7620 left rows.
# Processed 7630 left rows.
# Processed 7640 left rows.
# Processed 7650 left rows.
# Processed 7660 left rows.
# Processed 7670 left rows.
# Processed 7680 left rows.
# Processed 7690 left rows.
# Processed 7700 left rows.
# Processed 7710 left rows.
# Processed 7720 left rows.
# Processed 7730 left rows.
# Processed 7740 left rows.
# Processed 7750 left rows.
# Processed 7760 left rows.
# Processed 7770 left rows.
# Processed 7780 left rows.
# Processed 7790 left rows.
# Processed 7800 left rows.
# Processed 7810 left rows.
# Processed 7820 left rows.
# Processed 7830 left rows.
# Processed 7840 left rows.
# Processed 7850 left rows.
# Processed 7860 left rows.
# Processed 7870 left rows.
# Processed 7880 left rows.
# Processed 7890 left rows.
# Processed 7900 left rows.
# Processed 7910 left rows.
# Processed 7920 left rows.
# Processed 7930 left rows.
# Processed 7940 left rows.
# Processed 7950 left rows.
# Processed 7960 left rows.
# Processed 7970 left rows.
# Processed 7980 left rows.
# Processed 7990 left rows.
# Processed 8000 left rows.
# Processed 8010 left rows.
# Processed 8020 left rows.
# Processed 8030 left rows.
# Processed 8040 left rows.
# Processed 8050 left rows.
# Processed 8060 left rows.
# Processed 8070 left rows.
# Processed 8080 left rows.
# Processed 8090 left rows.
# Processed 8100 left rows.
# Processed 8110 left rows.
# Processed 8120 left rows.
# Processed 8130 left rows.
# Processed 8140 left rows.
# Processed 8150 left rows.
# Processed 8160 left rows.
# Processed 8170 left rows.
# Processed 8180 left rows.
# Processed 8190 left rows.
# Processed 8200 left rows.
# Processed 8210 left rows.
# Processed 8220 left rows.
# Processed 8230 left rows.
# Processed 8240 left rows.
# Processed 8250 left rows.
# Processed 8260 left rows.
# Processed 8270 left rows.
# Processed 8280 left rows.
# Processed 8290 left rows.
# Processed 8300 left rows.
# Processed 8310 left rows.
# Processed 8320 left rows.
# Processed 8330 left rows.
# Processed 8340 left rows.
# Processed 8350 left rows.
# Processed 8360 left rows.
# Processed 8370 left rows.
# Processed 8380 left rows.
# Processed 8390 left rows.
# Processed 8400 left rows.
# Processed 8410 left rows.
# Processed 8420 left rows.
# Processed 8430 left rows.
# Processed 8440 left rows.
# Processed 8450 left rows.
# Processed 8460 left rows.
# Processed 8470 left rows.
# Processed 8480 left rows.
# Processed 8490 left rows.
# Processed 8500 left rows.
# Processed 8510 left rows.
# Processed 8520 left rows.
# Processed 8530 left rows.
# Processed 8540 left rows.
# Processed 8550 left rows.
# Processed 8560 left rows.
# Processed 8570 left rows.
# Processed 8580 left rows.
# Processed 8590 left rows.
# Processed 8600 left rows.
# Processed 8610 left rows.
# Processed 8620 left rows.
# Processed 8630 left rows.
# Processed 8640 left rows.
# Processed 8650 left rows.
# Processed 8660 left rows.
# Processed 8670 left rows.
# Processed 8680 left rows.
# Processed 8690 left rows.
# Processed 8700 left rows.
# Processed 8710 left rows.
# Processed 8720 left rows.
# Processed 8730 left rows.
# Processed 8740 left rows.
# Processed 8750 left rows.
# Processed 8760 left rows.
# Processed 8770 left rows.
# Processed 8780 left rows.
# Processed 8790 left rows.
# Processed 8800 left rows.
# Processed 8810 left rows.
# Processed 8820 left rows.
# Processed 8830 left rows.
# Processed 8840 left rows.
# Processed 8850 left rows.
# Processed 8860 left rows.
# Processed 8870 left rows.
# Processed 8880 left rows.
# Processed 8890 left rows.
# Processed 8900 left rows.
# Processed 8910 left rows.
# Processed 8920 left rows.
# Processed 8930 left rows.
# Processed 8940 left rows.
# Processed 8950 left rows.
# Processed 8960 left rows.
# Processed 8970 left rows.
# Processed 8980 left rows.
# Processed 8990 left rows.
# Processed 9000 left rows.
# Processed 9010 left rows.
# Processed 9020 left rows.
# Processed 9030 left rows.
# Processed 9040 left rows.
# Processed 9050 left rows.
# Processed 9060 left rows.
# Processed 9070 left rows.
# Processed 9080 left rows.
# Processed 9090 left rows.
# Processed 9100 left rows.
# Processed 9110 left rows.
# Processed 9120 left rows.
# Processed 9130 left rows.
# Processed 9140 left rows.
# Processed 9150 left rows.
# Processed 9160 left rows.
# Processed 9170 left rows.
# Processed 9180 left rows.
# Processed 9190 left rows.
# Processed 9200 left rows.
# Processed 9210 left rows.
# Processed 9220 left rows.
# Processed 9230 left rows.
# Processed 9240 left rows.
# Processed 9250 left rows.
# Processed 9260 left rows.
# Processed 9270 left rows.
# Processed 9280 left rows.
# Processed 9290 left rows.
# Processed 9300 left rows.
# Processed 9310 left rows.
# Processed 9320 left rows.
# Processed 9330 left rows.
# Processed 9340 left rows.
# Processed 9350 left rows.
# Processed 9360 left rows.
# Processed 9370 left rows.
# Processed 9380 left rows.
# Processed 9390 left rows.
# Processed 9400 left rows.
# Processed 9410 left rows.
# Processed 9420 left rows.
# Processed 9430 left rows.
# Processed 9440 left rows.
# Processed 9450 left rows.
# Processed 9460 left rows.
# Processed 9470 left rows.
# Processed 9480 left rows.
# Processed 9490 left rows.
# Processed 9500 left rows.
# Processed 9510 left rows.
# Processed 9520 left rows.
# Processed 9530 left rows.
# Processed 9540 left rows.
# Processed 9550 left rows.
# Processed 9560 left rows.
# Processed 9570 left rows.
# Processed 9580 left rows.
# Processed 9590 left rows.
# Processed 9600 left rows.
# Processed 9610 left rows.
# Processed 9620 left rows.
# Processed 9630 left rows.
# Processed 9640 left rows.
# Processed 9650 left rows.
# Processed 9660 left rows.
# Processed 9670 left rows.
# Processed 9680 left rows.
# Processed 9690 left rows.
# Processed 9700 left rows.
# Processed 9710 left rows.
# Processed 9720 left rows.
# Processed 9730 left rows.
# Processed 9740 left rows.
# Processed 9750 left rows.
# Processed 9760 left rows.
# Processed 9770 left rows.
# Processed 9780 left rows.
# Processed 9790 left rows.
# Processed 9800 left rows.
# Processed 9810 left rows.
# Processed 9820 left rows.
# Processed 9830 left rows.
# Processed 9840 left rows.
# Processed 9850 left rows.
# Processed 9860 left rows.
# Processed 9870 left rows.
# Processed 9880 left rows.
# Processed 9890 left rows.
# Processed 9900 left rows.
# Processed 9910 left rows.
# Processed 9920 left rows.
# Processed 9930 left rows.
# Processed 9940 left rows.
# Processed 9950 left rows.
# Processed 9960 left rows.
# Processed 9970 left rows.
# Processed 9980 left rows.
# Processed 9990 left rows.
# Processed 10000 left rows.
# Processed 10010 left rows.
# Processed 10020 left rows.
# Processed 10030 left rows.
# Processed 10040 left rows.
# Processed 10050 left rows.
# Processed 10060 left rows.
# Processed 10070 left rows.
# Processed 10080 left rows.
# Processed 10090 left rows.
# Processed 10100 left rows.
# Processed 10110 left rows.
# Processed 10120 left rows.
# Processed 10130 left rows.
# Processed 10140 left rows.
# Processed 10150 left rows.
# Processed 10160 left rows.
# Processed 10170 left rows.
# Processed 10180 left rows.
# Processed 10190 left rows.
# Processed 10200 left rows.
# Processed 10210 left rows.
# Processed 10220 left rows.
# Processed 10230 left rows.
# Processed 10240 left rows.
# Processed 10250 left rows.
# Processed 10260 left rows.
# Processed 10270 left rows.
# Processed 10280 left rows.
# Processed 10290 left rows.
# Processed 10300 left rows.
# Processed 10310 left rows.
# Processed 10320 left rows.
# Processed 10330 left rows.
# Processed 10340 left rows.
# Processed 10350 left rows.
# Processed 10360 left rows.
# Processed 10370 left rows.
# Processed 10380 left rows.
# Processed 10390 left rows.
# Processed 10400 left rows.
# Processed 10410 left rows.
# Processed 10420 left rows.
# Processed 10430 left rows.
# Processed 10440 left rows.
# Processed 10450 left rows.
# Processed 10460 left rows.
# Processed 10470 left rows.
# Processed 10480 left rows.
# Processed 10490 left rows.
# Processed 10500 left rows.
# Processed 10510 left rows.
# Processed 10520 left rows.
# Processed 10530 left rows.
# Processed 10540 left rows.
# Processed 10550 left rows.
# Processed 10560 left rows.
# Processed 10570 left rows.
# Processed 10580 left rows.
# Processed 10590 left rows.
# Processed 10600 left rows.
# Processed 10610 left rows.
# Processed 10620 left rows.
# Processed 10630 left rows.
# Processed 10640 left rows.
# Processed 10650 left rows.
# Processed 10660 left rows.
# Processed 10670 left rows.
# Processed 10680 left rows.
# Processed 10690 left rows.
# Processed 10700 left rows.
# Processed 10710 left rows.
# Processed 10720 left rows.
# Processed 10730 left rows.
# Processed 10740 left rows.
# Processed 10750 left rows.
# Processed 10760 left rows.
# Processed 10770 left rows.
# Processed 10780 left rows.
# Processed 10790 left rows.
# Processed 10800 left rows.
# Processed 10810 left rows.
# Processed 10820 left rows.
# Processed 10830 left rows.
# Processed 10840 left rows.
# Processed 10850 left rows.
# Processed 10860 left rows.
# Processed 10870 left rows.
# Processed 10880 left rows.
# Processed 10890 left rows.
# Processed 10900 left rows.
# Processed 10910 left rows.
# Processed 10920 left rows.
# Processed 10930 left rows.
# Processed 10940 left rows.
# Processed 10950 left rows.
# Processed 10960 left rows.
# Processed 10970 left rows.
# Processed 10980 left rows.
# Processed 10990 left rows.
# Processed 11000 left rows.
# Processed 11010 left rows.
# Processed 11020 left rows.
# Processed 11030 left rows.
# Processed 11040 left rows.
# Processed 11050 left rows.
# Processed 11060 left rows.
# Processed 11070 left rows.
# Processed 11080 left rows.
# Processed 11090 left rows.
# Processed 11100 left rows.
# Processed 11110 left rows.
# Processed 11120 left rows.
# Processed 11130 left rows.
# Processed 11140 left rows.
# Processed 11150 left rows.
# Processed 11160 left rows.
# Processed 11170 left rows.
# Processed 11180 left rows.
# Processed 11190 left rows.
# Processed 11200 left rows.
# Processed 11210 left rows.
# Processed 11220 left rows.
# Processed 11230 left rows.
# Processed 11240 left rows.
# Processed 11250 left rows.
# Processed 11260 left rows.
# Processed 11270 left rows.
# Processed 11280 left rows.
# Processed 11290 left rows.
# Processed 11300 left rows.
# Processed 11310 left rows.
# Processed 11320 left rows.
# Processed 11330 left rows.
# Processed 11340 left rows.
# Processed 11350 left rows.
# Processed 11360 left rows.
# Processed 11370 left rows.
# Processed 11380 left rows.
# Processed 11390 left rows.
# Processed 11400 left rows.
# Processed 11410 left rows.
# Processed 11420 left rows.
# Processed 11430 left rows.
# Processed 11440 left rows.
# Processed 11450 left rows.
# Processed 11460 left rows.
# Processed 11470 left rows.
# Processed 11480 left rows.
# Processed 11490 left rows.
# Processed 11500 left rows.
# Processed 11510 left rows.
# Processed 11520 left rows.
# Processed 11530 left rows.
# Processed 11540 left rows.
# Processed 11550 left rows.
# Processed 11560 left rows.
# Processed 11570 left rows.
# Processed 11580 left rows.
# Processed 11590 left rows.
# Processed 11600 left rows.
# Processed 11610 left rows.
# Processed 11620 left rows.
# Processed 11630 left rows.
# Processed 11640 left rows.
# Processed 11650 left rows.
# Processed 11660 left rows.
# Processed 11670 left rows.
# Processed 11680 left rows.
# Processed 11690 left rows.
# Processed 11700 left rows.
# Processed 11710 left rows.
# Processed 11720 left rows.
# Processed 11730 left rows.
# Processed 11740 left rows.
# Processed 11750 left rows.
# Processed 11760 left rows.
# Processed 11770 left rows.
# Processed 11780 left rows.
# Processed 11790 left rows.
# Processed 11800 left rows.
# Processed 11810 left rows.
# Processed 11820 left rows.
# Processed 11830 left rows.
# Processed 11840 left rows.
# Processed 11850 left rows.
# Processed 11860 left rows.
# Processed 11870 left rows.
# Processed 11880 left rows.
# Processed 11890 left rows.
# Processed 11900 left rows.
# Processed 11910 left rows.
# Processed 11920 left rows.
# Processed 11930 left rows.
# Processed 11940 left rows.
# Processed 11950 left rows.
# Processed 11960 left rows.
# Processed 11970 left rows.
# Processed 11980 left rows.
# Processed 11990 left rows.
# Processed 12000 left rows.
# Processed 12010 left rows.
# Processed 12020 left rows.
# Processed 12030 left rows.
# Processed 12040 left rows.
# Processed 12050 left rows.
# Processed 12060 left rows.
# Processed 12070 left rows.
# Processed 12080 left rows.
# Processed 12090 left rows.
# Processed 12100 left rows.
# Processed 12110 left rows.
# Processed 12120 left rows.
# Processed 12130 left rows.
# Processed 12140 left rows.
# Processed 12150 left rows.
# Processed 12160 left rows.
# Processed 12170 left rows.
# Processed 12180 left rows.
# Processed 12190 left rows.
# Processed 12200 left rows.
# Processed 12210 left rows.
# Processed 12220 left rows.
# Processed 12230 left rows.
# Processed 12240 left rows.
# Processed 12250 left rows.
# Processed 12260 left rows.
# Processed 12270 left rows.
# Processed 12280 left rows.
# Processed 12290 left rows.
# Processed 12300 left rows.
# Processed 12310 left rows.
# Processed 12320 left rows.
# Processed 12330 left rows.
# Processed 12340 left rows.
# Processed 12350 left rows.
# Processed 12360 left rows.
# Processed 12370 left rows.
# Processed 12380 left rows.
# Processed 12390 left rows.
# Processed 12400 left rows.
# Processed 12410 left rows.
# Processed 12420 left rows.
# Processed 12430 left rows.
# Processed 12440 left rows.
# Processed 12450 left rows.
# Processed 12460 left rows.
# Processed 12470 left rows.
# Processed 12480 left rows.
# Processed 12490 left rows.
# Processed 12500 left rows.
# Processed 12510 left rows.
# Processed 12520 left rows.
# Processed 12530 left rows.
# Processed 12540 left rows.
# Processed 12550 left rows.
# Processed 12560 left rows.
# Processed 12570 left rows.
# Processed 12580 left rows.
# Processed 12590 left rows.
# Processed 12600 left rows.
# Processed 12610 left rows.
# Processed 12620 left rows.
# Processed 12630 left rows.
# Processed 12640 left rows.
# Processed 12650 left rows.
# Processed 12660 left rows.
# Processed 12670 left rows.
# Processed 12680 left rows.
# Processed 12690 left rows.
# Processed 12700 left rows.
# Processed 12710 left rows.
# Processed 12720 left rows.
# Processed 12730 left rows.
# Processed 12740 left rows.
# Processed 12750 left rows.
# Processed 12760 left rows.
# Processed 12770 left rows.
# Processed 12780 left rows.
# Processed 12790 left rows.
# Processed 12800 left rows.
# Processed 12810 left rows.
# Processed 12820 left rows.
# Processed 12830 left rows.
# Processed 12840 left rows.
# Processed 12850 left rows.
# Processed 12860 left rows.
# Processed 12870 left rows.
# Processed 12880 left rows.
# Processed 12890 left rows.
# Processed 12900 left rows.
# Processed 12910 left rows.
# Processed 12920 left rows.
# Processed 12930 left rows.
# Processed 12940 left rows.
# Processed 12950 left rows.
# Processed 12960 left rows.
# Processed 12970 left rows.
# Processed 12980 left rows.
# Processed 12990 left rows.
# Processed 13000 left rows.
# Processed 13010 left rows.
# Processed 13020 left rows.
# Processed 13030 left rows.
# Processed 13040 left rows.
# Processed 13050 left rows.
# Processed 13060 left rows.
# Processed 13070 left rows.
# Processed 13080 left rows.
# Processed 13090 left rows.
# Processed 13100 left rows.
# Processed 13110 left rows.
# Processed 13120 left rows.
# Processed 13130 left rows.
# Processed 13140 left rows.
# Processed 13150 left rows.
# Processed 13160 left rows.
# Processed 13170 left rows.
# Processed 13180 left rows.
# Processed 13190 left rows.
# Processed 13200 left rows.
# Processed 13210 left rows.
# Processed 13220 left rows.
# Processed 13230 left rows.
# Processed 13240 left rows.
# Processed 13250 left rows.
# Processed 13260 left rows.
# Processed 13270 left rows.
# Processed 13280 left rows.
# Processed 13290 left rows.
# Processed 13300 left rows.
# Processed 13310 left rows.
# Processed 13320 left rows.
# Processed 13330 left rows.
# Processed 13340 left rows.
# Processed 13350 left rows.
# Processed 13360 left rows.
# Processed 13370 left rows.
# Processed 13380 left rows.
# Processed 13390 left rows.
# Processed 13400 left rows.
# Processed 13410 left rows.
# Processed 13420 left rows.
# Processed 13430 left rows.
# Processed 13440 left rows.
# Processed 13450 left rows.
# Processed 13460 left rows.
# Processed 13470 left rows.
# Processed 13480 left rows.
# Processed 13490 left rows.
# Processed 13500 left rows.
# Processed 13510 left rows.
# Processed 13520 left rows.
# Processed 13530 left rows.
# Processed 13540 left rows.
# Processed 13550 left rows.
# Processed 13560 left rows.
# Processed 13570 left rows.
# Processed 13580 left rows.
# Processed 13590 left rows.
# Processed 13600 left rows.
# Processed 13610 left rows.
# Processed 13620 left rows.
# Processed 13630 left rows.
# Processed 13640 left rows.
# Processed 13650 left rows.
# Processed 13660 left rows.
# Processed 13670 left rows.
# Processed 13680 left rows.
# Processed 13690 left rows.
# Processed 13700 left rows.
# Processed 13710 left rows.
# Processed 13720 left rows.
# Processed 13730 left rows.
# Processed 13740 left rows.
# Processed 13750 left rows.
# Processed 13760 left rows.
# Processed 13770 left rows.
# Processed 13780 left rows.
# Processed 13790 left rows.
# Processed 13800 left rows.
# Processed 13810 left rows.
# Processed 13820 left rows.
# Processed 13830 left rows.
# Processed 13840 left rows.
# Processed 13850 left rows.
# Processed 13860 left rows.
# Processed 13870 left rows.
# Processed 13880 left rows.
# Processed 13890 left rows.
# Processed 13900 left rows.
# Processed 13910 left rows.
# Processed 13920 left rows.
# Processed 13930 left rows.
# Processed 13940 left rows.
# Processed 13950 left rows.
# Processed 13960 left rows.
# Processed 13970 left rows.
# Processed 13980 left rows.
# Processed 13990 left rows.
# Processed 14000 left rows.
# Processed 14010 left rows.
# Processed 14020 left rows.
# Processed 14030 left rows.
# Processed 14040 left rows.
# Processed 14050 left rows.
# Processed 14060 left rows.
# Processed 14070 left rows.
# Processed 14080 left rows.
# Processed 14090 left rows.
# Processed 14100 left rows.
# Processed 14110 left rows.
# Processed 14120 left rows.
# Processed 14130 left rows.
# Processed 14140 left rows.
# Processed 14150 left rows.
# Processed 14160 left rows.
# Processed 14170 left rows.
# Processed 14180 left rows.
# Processed 14190 left rows.
# Processed 14200 left rows.
# Processed 14210 left rows.
# Processed 14220 left rows.
# Processed 14230 left rows.
# Processed 14240 left rows.
# Processed 14250 left rows.
# Processed 14260 left rows.
# Processed 14270 left rows.
# Processed 14280 left rows.
# Processed 14290 left rows.
# Processed 14300 left rows.
# Processed 14310 left rows.
# Processed 14320 left rows.
# Processed 14330 left rows.
# Processed 14340 left rows.
# Processed 14350 left rows.
# Processed 14360 left rows.
# Processed 14370 left rows.
# Processed 14380 left rows.
# Processed 14390 left rows.
# Processed 14400 left rows.
# Processed 14410 left rows.
# Processed 14420 left rows.
# Processed 14430 left rows.
# Processed 14440 left rows.
# Processed 14450 left rows.
# Processed 14460 left rows.
# Processed 14470 left rows.
# Processed 14480 left rows.
# Processed 14490 left rows.
# Processed 14500 left rows.
# Processed 14510 left rows.
# Processed 14520 left rows.
# Processed 14530 left rows.
# Processed 14540 left rows.
# Processed 14550 left rows.
# Processed 14560 left rows.
# Processed 14570 left rows.
# Processed 14580 left rows.
# Processed 14590 left rows.
# Processed 14600 left rows.
# Processed 14610 left rows.
# Processed 14620 left rows.
# Processed 14630 left rows.
# Processed 14640 left rows.
# Processed 14650 left rows.
# Processed 14660 left rows.
# Processed 14670 left rows.
# Processed 14680 left rows.
# Processed 14690 left rows.
# Processed 14700 left rows.
# Processed 14710 left rows.
# Processed 14720 left rows.
# Processed 14730 left rows.
# Processed 14740 left rows.
# Processed 14750 left rows.
# Processed 14760 left rows.
# Processed 14770 left rows.
# Processed 14780 left rows.
# Processed 14790 left rows.
# Processed 14800 left rows.
# Processed 14810 left rows.
# Processed 14820 left rows.
# Processed 14830 left rows.
# Processed 14840 left rows.
# Processed 14850 left rows.
# Processed 14860 left rows.
# Processed 14870 left rows.
# Processed 14880 left rows.
# Processed 14890 left rows.
# Processed 14900 left rows.
# Processed 14910 left rows.
# Processed 14920 left rows.
# Processed 14930 left rows.
# Processed 14940 left rows.
# Processed 14950 left rows.
# Processed 14960 left rows.
# Processed 14970 left rows.
# Processed 14980 left rows.
# Processed 14990 left rows.
# Processed 15000 left rows.
# Processed 15010 left rows.
# Processed 15020 left rows.
# Processed 15030 left rows.
# Processed 15040 left rows.
# Processed 15050 left rows.
# Processed 15060 left rows.
# Processed 15070 left rows.
# Processed 15080 left rows.
# Processed 15090 left rows.
# Processed 15100 left rows.
# Processed 15110 left rows.
# Processed 15120 left rows.
# Processed 15130 left rows.
# Processed 15140 left rows.
# Processed 15150 left rows.
# Processed 15160 left rows.
# Processed 15170 left rows.
# Processed 15180 left rows.
# Processed 15190 left rows.
# Processed 15200 left rows.
# Processed 15210 left rows.
# Processed 15220 left rows.
# Processed 15230 left rows.
# Processed 15240 left rows.
# Processed 15250 left rows.
# Processed 15260 left rows.
# Processed 15270 left rows.
# Processed 15280 left rows.
# Processed 15290 left rows.
# Processed 15300 left rows.
# Processed 15310 left rows.
# Processed 15320 left rows.
# Processed 15330 left rows.
# Processed 15340 left rows.
# Processed 15350 left rows.
# Processed 15360 left rows.
# Processed 15370 left rows.
# Processed 15380 left rows.
# Processed 15390 left rows.
# Processed 15400 left rows.
# Processed 15410 left rows.
# Processed 15420 left rows.
# Processed 15430 left rows.
# Processed 15440 left rows.
# Processed 15450 left rows.
# Processed 15460 left rows.
# Processed 15470 left rows.
# Processed 15480 left rows.
# Processed 15490 left rows.
# Processed 15500 left rows.
# Processed 15510 left rows.
# Processed 15520 left rows.
# Processed 15530 left rows.
# Processed 15540 left rows.
# Processed 15550 left rows.
# Processed 15560 left rows.
# Processed 15570 left rows.
# Processed 15580 left rows.
# Processed 15590 left rows.
# Processed 15600 left rows.
# Processed 15610 left rows.
# Processed 15620 left rows.
# Processed 15630 left rows.
# Processed 15640 left rows.
# Processed 15650 left rows.
# Processed 15660 left rows.
# Processed 15670 left rows.
# Processed 15680 left rows.
# Processed 15690 left rows.
# Processed 15700 left rows.
# Processed 15710 left rows.
# Processed 15720 left rows.
# Processed 15730 left rows.
# Processed 15740 left rows.
# Processed 15750 left rows.
# Processed 15760 left rows.
# Processed 15770 left rows.
# Processed 15780 left rows.
# Processed 15790 left rows.
# Processed 15800 left rows.
# Processed 15810 left rows.
# Processed 15820 left rows.
# Processed 15830 left rows.
# Processed 15840 left rows.
# Processed 15850 left rows.
# Processed 15860 left rows.
# Processed 15870 left rows.
# Processed 15880 left rows.
# Processed 15890 left rows.
# Processed 15900 left rows.
# Processed 15910 left rows.
# Processed 15920 left rows.
# Processed 15930 left rows.
# Processed 15940 left rows.
# Processed 15950 left rows.
# Processed 15960 left rows.
# Processed 15970 left rows.
# Processed 15980 left rows.
# Processed 15990 left rows.
# Processed 16000 left rows.
# Processed 16010 left rows.
# Processed 16020 left rows.
# Processed 16030 left rows.
# Processed 16040 left rows.
# Processed 16050 left rows.
# Processed 16060 left rows.
# Processed 16070 left rows.
# Processed 16080 left rows.
# Processed 16090 left rows.
# Processed 16100 left rows.
# Processed 16110 left rows.
# Processed 16120 left rows.
# Processed 16130 left rows.
# Processed 16140 left rows.
# Processed 16150 left rows.
# Processed 16160 left rows.
# Processed 16170 left rows.
# Processed 16180 left rows.
# Processed 16190 left rows.
# Processed 16200 left rows.
# Processed 16210 left rows.
# Processed 16220 left rows.
# Processed 16230 left rows.
# Processed 16240 left rows.
# Processed 16250 left rows.
# Processed 16260 left rows.
# Processed 16270 left rows.
# Processed 16280 left rows.
# Processed 16290 left rows.
# Processed 16300 left rows.
# Processed 16310 left rows.
# Processed 16320 left rows.
# Processed 16330 left rows.
# Processed 16340 left rows.
# Processed 16350 left rows.
# Processed 16360 left rows.
# Processed 16370 left rows.
# Processed 16380 left rows.
# Processed 16390 left rows.
# Processed 16400 left rows.
# Processed 16410 left rows.
# Processed 16420 left rows.
# Processed 16430 left rows.
# Processed 16440 left rows.
# Processed 16450 left rows.
# Processed 16460 left rows.
# Processed 16470 left rows.
# Processed 16480 left rows.
# Processed 16490 left rows.
# Processed 16500 left rows.
# Processed 16510 left rows.
# Processed 16520 left rows.
# Processed 16530 left rows.
# Processed 16540 left rows.
# Processed 16550 left rows.
# Processed 16560 left rows.
# Processed 16570 left rows.
# Processed 16580 left rows.
# Processed 16590 left rows.
# Processed 16600 left rows.
# Processed 16610 left rows.
# Processed 16620 left rows.
# Processed 16630 left rows.
# Processed 16640 left rows.
# Processed 16650 left rows.
# Processed 16660 left rows.
# Processed 16670 left rows.
# Processed 16680 left rows.
# Processed 16690 left rows.
# Processed 16700 left rows.
# Processed 16710 left rows.
# Processed 16720 left rows.
# Processed 16730 left rows.
# Processed 16740 left rows.
# Processed 16750 left rows.
# Processed 16760 left rows.
# Processed 16770 left rows.
# Processed 16780 left rows.
# Processed 16790 left rows.
# Processed 16800 left rows.
# Processed 16810 left rows.
# Processed 16820 left rows.
# Processed 16830 left rows.
# Processed 16840 left rows.
# Processed 16850 left rows.
# Processed 16860 left rows.
# Processed 16870 left rows.
# Processed 16880 left rows.
# Processed 16890 left rows.
# Processed 16900 left rows.
# Processed 16910 left rows.
# Processed 16920 left rows.
# Processed 16930 left rows.
# Processed 16940 left rows.
# Processed 16950 left rows.
# Processed 16960 left rows.
# Processed 16970 left rows.
# Processed 16980 left rows.
# Processed 16990 left rows.
# Processed 17000 left rows.
# Processed 17010 left rows.
# Processed 17020 left rows.
# Processed 17030 left rows.
# Processed 17040 left rows.
# Processed 17050 left rows.
# Processed 17060 left rows.
# Processed 17070 left rows.
# Processed 17080 left rows.
# Processed 17090 left rows.
# Processed 17100 left rows.
# Processed 17110 left rows.
# Processed 17120 left rows.
# Processed 17130 left rows.
# Processed 17140 left rows.
# Processed 17150 left rows.
# Processed 17160 left rows.
# Processed 17170 left rows.
# Processed 17180 left rows.
# Processed 17190 left rows.
# Processed 17200 left rows.
# Processed 17210 left rows.
# Processed 17220 left rows.
# Processed 17230 left rows.
# Processed 17240 left rows.
# Processed 17250 left rows.
# Processed 17260 left rows.
# Processed 17270 left rows.
# Processed 17280 left rows.
# Processed 17290 left rows.
# Processed 17300 left rows.
# Processed 17310 left rows.
# Processed 17320 left rows.
# Processed 17330 left rows.
# Processed 17340 left rows.
# Processed 17350 left rows.
# Processed 17360 left rows.
# Processed 17370 left rows.
# Processed 17380 left rows.
# Processed 17390 left rows.
# Processed 17400 left rows.
# Processed 17410 left rows.
# Processed 17420 left rows.
# Processed 17430 left rows.
# Processed 17440 left rows.
# Processed 17450 left rows.
# Processed 17460 left rows.
# Processed 17470 left rows.
# Processed 17480 left rows.
# Processed 17490 left rows.
# Processed 17500 left rows.
# Processed 17510 left rows.
# Processed 17520 left rows.
# Processed 17530 left rows.
# Processed 17540 left rows.
# Processed 17550 left rows.
# Processed 17560 left rows.
# Processed 17570 left rows.
# Processed 17580 left rows.
# Processed 17590 left rows.
# Processed 17600 left rows.
# Processed 17610 left rows.
# Processed 17620 left rows.
# Processed 17630 left rows.
# Processed 17640 left rows.
# Processed 17650 left rows.
# Processed 17660 left rows.
# Processed 17670 left rows.
# Processed 17680 left rows.
# Processed 17690 left rows.
# Processed 17700 left rows.
# Processed 17710 left rows.
# Processed 17720 left rows.
# Processed 17730 left rows.
# Processed 17740 left rows.
# Processed 17750 left rows.
# Processed 17760 left rows.
# Processed 17770 left rows.
# Processed 17780 left rows.
# Processed 17790 left rows.
# Processed 17800 left rows.
# Processed 17810 left rows.
# Processed 17820 left rows.
# Processed 17830 left rows.
# Processed 17840 left rows.
# Processed 17850 left rows.
# Processed 17860 left rows.
# Processed 17870 left rows.
# Processed 17880 left rows.
# Processed 17890 left rows.
# Processed 17900 left rows.
# Processed 17910 left rows.
# Processed 17920 left rows.
# Processed 17930 left rows.
# Processed 17940 left rows.
# Processed 17950 left rows.
# Processed 17960 left rows.
# Processed 17970 left rows.
# Processed 17980 left rows.
# Processed 17990 left rows.
# Processed 18000 left rows.
# Processed 18010 left rows.
# Processed 18020 left rows.
# Processed 18030 left rows.
# Processed 18040 left rows.
# Processed 18050 left rows.
# Processed 18060 left rows.
# Processed 18070 left rows.
# Processed 18080 left rows.
# Processed 18090 left rows.
# Processed 18100 left rows.
# Processed 18110 left rows.
# Processed 18120 left rows.
# Processed 18130 left rows.
# Processed 18140 left rows.
# Processed 18150 left rows.
# Processed 18160 left rows.
# Processed 18170 left rows.
# Processed 18180 left rows.
# Processed 18190 left rows.
# Processed 18200 left rows.
# Processed 18210 left rows.
# Processed 18220 left rows.
# Processed 18230 left rows.
# Processed 18240 left rows.
# Processed 18250 left rows.
# Processed 18260 left rows.
# Processed 18270 left rows.
# Processed 18280 left rows.
# Processed 18290 left rows.
# Processed 18300 left rows.
# Processed 18310 left rows.
# Processed 18320 left rows.
# Processed 18330 left rows.
# Processed 18340 left rows.
# Processed 18350 left rows.
# Processed 18360 left rows.
# Processed 18370 left rows.
# Processed 18380 left rows.
# Processed 18390 left rows.
# Processed 18400 left rows.
# Processed 18410 left rows.
# Processed 18420 left rows.
# Processed 18430 left rows.
# Processed 18440 left rows.
# Processed 18450 left rows.
# Processed 18460 left rows.
# Processed 18470 left rows.
# Processed 18480 left rows.
# Processed 18490 left rows.
# Processed 18500 left rows.
# Processed 18510 left rows.
# Processed 18520 left rows.
# Processed 18530 left rows.
# Processed 18540 left rows.
# Processed 18550 left rows.
# Processed 18560 left rows.
# Processed 18570 left rows.
# Processed 18580 left rows.
# Processed 18590 left rows.
# Processed 18600 left rows.
# Processed 18610 left rows.
# Processed 18620 left rows.
# Processed 18630 left rows.
# Processed 18640 left rows.
# Processed 18650 left rows.
# Processed 18660 left rows.
# Processed 18670 left rows.
# Processed 18680 left rows.
# Processed 18690 left rows.
# Processed 18700 left rows.
# Processed 18710 left rows.
# Processed 18720 left rows.
# Processed 18730 left rows.
# Processed 18740 left rows.
# Processed 18750 left rows.
# Processed 18760 left rows.
# Processed 18770 left rows.
# Processed 18780 left rows.
# Processed 18790 left rows.
# Processed 18800 left rows.
# Processed 18810 left rows.
# Processed 18820 left rows.
# Processed 18830 left rows.
# Processed 18840 left rows.
# Processed 18850 left rows.
# Processed 18860 left rows.
# Processed 18870 left rows.
# Processed 18880 left rows.
# Processed 18890 left rows.
# Processed 18900 left rows.
# Processed 18910 left rows.
# Processed 18920 left rows.
# Processed 18930 left rows.
# Processed 18940 left rows.
# Processed 18950 left rows.
# Processed 18960 left rows.
# Processed 18970 left rows.
# Processed 18980 left rows.
# Processed 18990 left rows.
# Processed 19000 left rows.
# Processed 19010 left rows.
# Processed 19020 left rows.
# Processed 19030 left rows.
# Processed 19040 left rows.
# Processed 19050 left rows.
# Processed 19060 left rows.
# Processed 19070 left rows.
# Processed 19080 left rows.
# Processed 19090 left rows.
# Processed 19100 left rows.
# Processed 19110 left rows.
# Processed 19120 left rows.
# Processed 19130 left rows.
# Processed 19140 left rows.
# Processed 19150 left rows.
# Processed 19160 left rows.
# Processed 19170 left rows.
# Processed 19180 left rows.
# Processed 19190 left rows.
# Processed 19200 left rows.
# Processed 19210 left rows.
# Processed 19220 left rows.
# Processed 19230 left rows.
# Processed 19240 left rows.
# Processed 19250 left rows.
# Processed 19260 left rows.
# Processed 19270 left rows.
# Processed 19280 left rows.
# Processed 19290 left rows.
# Processed 19300 left rows.
# Processed 19310 left rows.
# Processed 19320 left rows.
# Processed 19330 left rows.
# Processed 19340 left rows.
# Processed 19350 left rows.
# Processed 19360 left rows.
# Processed 19370 left rows.
# +------------+----------+----------+-------------+------------+---------+
# | playerID   |   yearID | teamID   | nameFirst   | nameLast   |   G_all |
# +============+==========+==========+=============+============+=========+
# | baxtemi01  |     2010 | SDN      | Mike        | Baxter     |       9 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2011 | NYN      | Mike        | Baxter     |      22 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2012 | NYN      | Mike        | Baxter     |      89 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2013 | NYN      | Mike        | Baxter     |      74 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2014 | LAN      | Mike        | Baxter     |       4 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2015 | CHN      | Mike        | Baxter     |      34 |
# +------------+----------+----------+-------------+------------+---------+
# CPU times: user 18min 21s, sys: 10 s, total: 18min 31s
# Wall time: 18min 47s

# %%
# %%time
tab.smart_join_test()
# Out:
# Running load core definition
# Q =  select * from csvtables where table_name = 'people'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'people'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'people' group by index_name, table_name, type, column_name, index_order order by index_order
# Running load core definition
# Q =  select * from csvtables where table_name = 'appearances'
# Running load columns
# Q =  select * from csvcolumns where table_name = 'appearances'
# Running load indexes
# Q =  select * from csvindexes where table_name = 'appearances' group by index_name, table_name, type, column_name, index_order order by index_order
# +------------+----------+----------+-------------+------------+---------+
# | playerID   |   yearID | teamID   | nameFirst   | nameLast   |   G_all |
# +============+==========+==========+=============+============+=========+
# | baxtemi01  |     2010 | SDN      | Mike        | Baxter     |       9 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2011 | NYN      | Mike        | Baxter     |      22 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2012 | NYN      | Mike        | Baxter     |      89 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2013 | NYN      | Mike        | Baxter     |      74 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2014 | LAN      | Mike        | Baxter     |       4 |
# +------------+----------+----------+-------------+------------+---------+
# | baxtemi01  |     2015 | CHN      | Mike        | Baxter     |      34 |
# +------------+----------+----------+-------------+------------+---------+
# CPU times: user 1.2 s, sys: 221 ms, total: 1.42 s
# Wall time: 1.59 s
